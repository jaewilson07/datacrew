# %% [markdown]
# # Postman Collection Converter
#
# This notebook demonstrates how to convert Postman collections to Python API client code using the PostmanCollectionConverter library.
#
#
# ```mermaid
# flowchart TD
#     A["Postman API"] --introduce consistency via modeling --> B["models.py"]
#     B -- integration benefits from consistent classes  --> C["converter.py"]
#     C  -- users appreciate classes with thought out methods --> D["implementation.ipynb"]
# ```

# %% [markdown]
# ## Class Flow
#
# ```mermaid
# flowchart TD
#     JSON["Postman Collection JSON"]
#
#     subgraph Parsing["API Modeling Phase"]
#         JSON -- from api / json --> Collection["PostmanCollection"]
#         Collection -- contains many --> Requests["PostmanRequest Objects"]
#     end
#
#     subgraph Converting["Conversion Phase"]
#         Requests -- Convert --> RequestConverter["PostmanRequestConverter"]
#         RequestConverter -- Generates -->  Code["Python function string"]
#         Code -- Write --> Files["export/files.py"]
#     end
#
#
# ```

# %%
import os

from _1_models import PostmanCollection
from _2_converter import PostmanCollectionConverter, PostmanRequestConverter
from _2_tester import test_exports

# %% [markdown]
# ## Load a Postman Collection
#
# First, let's load a Postman collection from a JSON file.

# %%
# Replace this with your Postman collection path
collection_path = "demo.postman_collection.json"

# Define the output directory
output_dir = "./EXPORT/demo/"

# Load the collection from a file
collection = PostmanCollection.from_file(collection_path)
from pprint import pprint
# pprint(collection.info.__dict__)
# collection.list_all_params()


pprint(collection.requests[0].header)
# Out:
# [PostmanRequest_Header(key='host', value='domo-community.domo.com'),
#  PostmanRequest_Header(key='accept', value='*/*'),
#  PostmanRequest_Header(key='sec-ch-ua',
#                        value='"Google Chrome";v="135", "Not-A.Brand";v="8", '
#                              '"Chromium";v="135"'),
#  PostmanRequest_Header(key='user-agent',
#                        value='Mozilla/5.0 (Windows NT 10.0; Win64; x64) '
#                              'AppleWebKit/537.36 (KHTML, like Gecko) '
#                              'Chrome/135.0.0.0 Safari/537.36'),
#  PostmanRequest_Header(key='content-type', value='application/json'),
#  PostmanRequest_Header(key='x-csrf-token',
#                        value='06f9eacc-f729-4d59-93a9-0ef11721048c'),
#  PostmanRequest_Header(key='sec-fetch-dest', value='empty'),
#  PostmanRequest_Header(key='sec-fetch-mode', value='cors'),
#  PostmanRequest_Header(key='sec-fetch-site', value='same-origin'),
#  PostmanRequest_Header(key='x-requested-with', value='XMLHttpRequest'),
#  PostmanRequest_Header(key='sec-ch-ua-mobile', value='?0'),
#  PostmanRequest_Header(key='sec-ch-ua-platform', value='"Windows"'),
#  PostmanRequest_Header(key='x-domo-requestcontext',
#                        value='{"clientToe":"C5MAH5D893-35IJG"}')]

# %% [markdown]
# ## Customize the Conversion
#
# Let's define some customization options for specific functions.

# %%
# Define default headers to include in all requests
default_required_headers = ['accept', 'content-type']

# Customization options for specific endpoints
customizations = {
    # Function name -> customization options
    "get_cards": {
        "default_params": [ "parts", "includeFiltered"],
        "ignored_params" : ["urns", "includeFiltered"],
    }
}

# %% [markdown]
# ## Generate Python API Client Files
#
# Now let's generate the Python API client files from the Postman collection.

# %%
converter = PostmanCollectionConverter.from_postman_collection(
    postman_path=collection_path,
    export_folder=output_dir,
    customize=customizations,
    required_headers=default_required_headers  # Pass global required headers
)
# Out:
# Exported function to ./EXPORT/demo/search_post.py
# Exported function to ./EXPORT/demo/query_post.py
# Exported function to ./EXPORT/demo/savedqueryprofiledatacenter_get.py
# Exported function to ./EXPORT/demo/authenticate_post.py
# Exported function to ./EXPORT/demo/providers_get.py
# Exported function to ./EXPORT/demo/adapters_get.py
# Exported function to ./EXPORT/demo/athena_federated_get.py
# Exported function to ./EXPORT/demo/oracle_federated_get.py
# Exported function to ./EXPORT/demo/snowflake_federated_keypair_get.py
# Exported function to ./EXPORT/demo/snowflake_federated_get.py
# Exported function to ./EXPORT/demo/postgres_federated_get.py
# Exported function to ./EXPORT/demo/watson_federated_get.py
# Exported function to ./EXPORT/demo/teradata_federated_get.py
# Exported function to ./EXPORT/demo/azure_federated_get.py
# Exported function to ./EXPORT/demo/vertica_federated_get.py
# Exported function to ./EXPORT/demo/presto_federated_get.py
# Exported function to ./EXPORT/demo/bigquery_federated_get.py
# Exported function to ./EXPORT/demo/redshift_federated_get.py
# Exported function to ./EXPORT/demo/sqlserver_federated_get.py
# Exported function to ./EXPORT/demo/trino_federated_get.py
# Exported function to ./EXPORT/demo/db2_federated_get.py
# Exported function to ./EXPORT/demo/snowflake_federated_oauth_get.py
# Exported function to ./EXPORT/demo/bigquery_federated_oauth_get.py
# Exported function to ./EXPORT/demo/mysql_federated_get.py
# Exported function to ./EXPORT/demo/hana_federated_get.py
# Exported function to ./EXPORT/demo/clickdata_post.py
# Exported function to ./EXPORT/demo/1674a436_2f80_4abd_8191_d84634b41702_get.py
# Exported function to ./EXPORT/demo/free_invite_get.py
# Exported function to ./EXPORT/demo/configfeaturedatacenter_1674a436_2f80_4abd_8191_d84634b41702_get.py
# Exported function to ./EXPORT/demo/indexedincludehiddentrue_get.py
# Exported function to ./EXPORT/demo/list_post.py
# Exported function to ./EXPORT/demo/1267fieldsall_get.py
# Exported function to ./EXPORT/demo/1674a436_2f80_4abd_8191_d84634b41702_get.py
# Exported function to ./EXPORT/demo/1674a436_2f80_4abd_8191_d84634b41702_get.py
# Exported function to ./EXPORT/demo/bulkincludeprivatetrueincludealldetailstrue_post.py
# Exported function to ./EXPORT/demo/model_get.py
# Exported function to ./EXPORT/demo/search_post.py
# Exported function to ./EXPORT/demo/1674a436_2f80_4abd_8191_d84634b41702_get.py
# Exported function to ./EXPORT/demo/access_post.py
# Exported function to ./EXPORT/demo/nocompute_get.py
# Exported function to ./EXPORT/demo/1674a436_2f80_4abd_8191_d84634b41702traversedownfalse_get.py
# Exported function to ./EXPORT/demo/me_post.py
# Exported function to ./EXPORT/demo/logview_post.py
# Exported function to ./EXPORT/demo/1674a436_2f80_4abd_8191_d84634b41702_post.py
# Exported function to ./EXPORT/demo/domoweb_post.py
# Exported function to ./EXPORT/demo/1674a436_2f80_4abd_8191_d84634b41702_post.py
# Exported function to ./EXPORT/demo/1674a436_2f80_4abd_8191_d84634b41702_put.py
# Exported function to ./EXPORT/demo/activitypartsattributessize100sortdate_get.py
# Exported function to ./EXPORT/demo/counts_put.py
# Exported function to ./EXPORT/demo/renderpartsimage_put.py
# Exported function to ./EXPORT/demo/2139745814_get.py
# Exported function to ./EXPORT/demo/suggest_post.py
# Exported function to ./EXPORT/demo/153795447size100defaultbackground555555defaultforegroundeeeeeedefaulttextgd_get.py
# Exported function to ./EXPORT/demo/indexcvuserids19502083318041042291715220978_get.py
# Exported function to ./EXPORT/demo/1950208331size100cachebuster1744090976695_get.py
# Exported function to ./EXPORT/demo/getignorecachefalseincludeactivefalseincludeusersfalse_post.py
# Exported function to ./EXPORT/demo/clog_post.py
# Exported function to ./EXPORT/demo/domopolicymanaged_last_export_get.py
# Exported function to ./EXPORT/demo/domopolicymanaged_last_export_date_get.py
# Exported function to ./EXPORT/demo/roles_get.py
# Exported function to ./EXPORT/demo/searchexplainfalse_post.py
# Exported function to ./EXPORT/demo/keyskeyspacescustomer_defined_get.py
# Exported function to ./EXPORT/demo/create_post.py
# Exported function to ./EXPORT/demo/1950208331_get.py
# Exported function to ./EXPORT/demo/teams_get.py
# Exported function to ./EXPORT/demo/authorities_get.py
# Exported function to ./EXPORT/demo/titlelimit1000000offset0search_get.py
# Exported function to ./EXPORT/demo/departmentlimit1000000offset0search_get.py
# Exported function to ./EXPORT/demo/userroleiddefaultdefaultvalue2ignorecachetrue_get.py
# Exported function to ./EXPORT/demo/2097317660_get.py
# Exported function to ./EXPORT/demo/userrolesallowlist_get.py
# Exported function to ./EXPORT/demo/1950208331_patch.py
# Exported function to ./EXPORT/demo/1950208331includedetailstrueincludetrialdetailstrue_get.py
# Exported function to ./EXPORT/demo/1950208331_get.py
# Exported function to ./EXPORT/demo/profiles_get.py
# Exported function to ./EXPORT/demo/0f7e7731_67ac_431c_b01d_e9ec4da59b7apartsversions_get.py
# Exported function to ./EXPORT/demo/permissions_get.py
# Exported function to ./EXPORT/demo/102partsfunctionscode_get.py
# Exported function to ./EXPORT/demo/providersfieldskeyname_get.py

# %% [markdown]
# ## Test the Generated API Client
#
# Now we can test our generated API client functions.

# %%
# Define auth credentials
auth = {
    "base_url": "https://domo-community.domo.com",
    "headers": {
        "x-domo-developer-token": os.environ["DOMO_ACCESS_TOKEN"],
        "base_url": f"https://{os.environ['domo_instance']}.domo.com",
    }
}



# Test the exported functions (commented out to avoid making actual API calls)
results = test_exports(
    export_folder=output_dir,
    auth=auth,
    debug_api=True,
    update_files=True
)
# Out:
# Testing module 0f7e7731_67ac_431c_b01d_e9ec4da59b7apartsversions_get from ./EXPORT/demo/0f7e7731_67ac_431c_b01d_e9ec4da59b7apartsversions_get.py...
# Error loading module 0f7e7731_67ac_431c_b01d_e9ec4da59b7apartsversions_get.py: invalid decimal literal (./EXPORT/demo/0f7e7731_67ac_431c_b01d_e9ec4da59b7apartsversions_get.py, line 6)
# Testing module 102partsfunctionscode_get from ./EXPORT/demo/102partsfunctionscode_get.py...
# Error loading module 102partsfunctionscode_get.py: invalid decimal literal (./EXPORT/demo/102partsfunctionscode_get.py, line 6)
# Testing module 1267fieldsall_get from ./EXPORT/demo/1267fieldsall_get.py...
# Error loading module 1267fieldsall_get.py: invalid decimal literal (./EXPORT/demo/1267fieldsall_get.py, line 6)
# Testing module 153795447size100defaultbackground555555defaultforegroundeeeeeedefaulttextgd_get from ./EXPORT/demo/153795447size100defaultbackground555555defaultforegroundeeeeeedefaulttextgd_get.py...
# Error loading module 153795447size100defaultbackground555555defaultforegroundeeeeeedefaulttextgd_get.py: invalid decimal literal (./EXPORT/demo/153795447size100defaultbackground555555defaultforegroundeeeeeedefaulttextgd_get.py, line 6)
# Testing module 1674a436_2f80_4abd_8191_d84634b41702traversedownfalse_get from ./EXPORT/demo/1674a436_2f80_4abd_8191_d84634b41702traversedownfalse_get.py...
# Error loading module 1674a436_2f80_4abd_8191_d84634b41702traversedownfalse_get.py: invalid decimal literal (./EXPORT/demo/1674a436_2f80_4abd_8191_d84634b41702traversedownfalse_get.py, line 6)
# Testing module 1674a436_2f80_4abd_8191_d84634b41702_get from ./EXPORT/demo/1674a436_2f80_4abd_8191_d84634b41702_get.py...
# Error loading module 1674a436_2f80_4abd_8191_d84634b41702_get.py: invalid decimal literal (./EXPORT/demo/1674a436_2f80_4abd_8191_d84634b41702_get.py, line 6)
# Testing module 1674a436_2f80_4abd_8191_d84634b41702_post from ./EXPORT/demo/1674a436_2f80_4abd_8191_d84634b41702_post.py...
# Error loading module 1674a436_2f80_4abd_8191_d84634b41702_post.py: invalid decimal literal (./EXPORT/demo/1674a436_2f80_4abd_8191_d84634b41702_post.py, line 6)
# Testing module 1674a436_2f80_4abd_8191_d84634b41702_put from ./EXPORT/demo/1674a436_2f80_4abd_8191_d84634b41702_put.py...
# Error loading module 1674a436_2f80_4abd_8191_d84634b41702_put.py: invalid decimal literal (./EXPORT/demo/1674a436_2f80_4abd_8191_d84634b41702_put.py, line 6)
# Testing module 1950208331includedetailstrueincludetrialdetailstrue_get from ./EXPORT/demo/1950208331includedetailstrueincludetrialdetailstrue_get.py...
# Error loading module 1950208331includedetailstrueincludetrialdetailstrue_get.py: invalid syntax (./EXPORT/demo/1950208331includedetailstrueincludetrialdetailstrue_get.py, line 6)
# Testing module 1950208331size100cachebuster1744090976695_get from ./EXPORT/demo/1950208331size100cachebuster1744090976695_get.py...
# Error loading module 1950208331size100cachebuster1744090976695_get.py: invalid decimal literal (./EXPORT/demo/1950208331size100cachebuster1744090976695_get.py, line 6)
# Testing module 1950208331_get from ./EXPORT/demo/1950208331_get.py...
# Error loading module 1950208331_get.py: invalid decimal literal (./EXPORT/demo/1950208331_get.py, line 6)
# Testing module 1950208331_patch from ./EXPORT/demo/1950208331_patch.py...
# Error loading module 1950208331_patch.py: invalid decimal literal (./EXPORT/demo/1950208331_patch.py, line 6)
# Testing module 2097317660_get from ./EXPORT/demo/2097317660_get.py...
# Error loading module 2097317660_get.py: invalid decimal literal (./EXPORT/demo/2097317660_get.py, line 6)
# Testing module 2139745814_get from ./EXPORT/demo/2139745814_get.py...
# Error loading module 2139745814_get.py: invalid decimal literal (./EXPORT/demo/2139745814_get.py, line 6)
# Testing module access_post from ./EXPORT/demo/access_post.py...
# Testing access_post.access_post...
# 🚀 Making post request to https://domo-community.domo.com/api/query/v1/views/access
# Headers: {'accept': 'application/json, text/plain, */*', 'content-type': 'application/json;charset=utf-8', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {}
# Data: None
# JSON: None
# d:\GitHub\datacrew\postman\./EXPORT/demo/1950208331includedetailstrueincludetrialdetailstrue_get.py:6: SyntaxWarning: invalid decimal literal
#   def 1950208331includedetailstrueincludetrialdetailstrue_get( auth: Dict[str, str], debug_api: bool = False ) -> requests.Response:
# d:\GitHub\datacrew\postman\./EXPORT/demo/1950208331includedetailstrueincludetrialdetailstrue_get.py:24: SyntaxWarning: invalid decimal literal
#   response = 1950208331includedetailstrueincludetrialdetailstrue_get(auth = auth, debug_api = debug_api, )
#   Status: 400
# Running test function access_post.test_access_post...
#   Error: Expected status code 200, got {response.status_code}
# Updated access_post.py with test results
# Testing module activitypartsattributessize100sortdate_get from ./EXPORT/demo/activitypartsattributessize100sortdate_get.py...
# Testing activitypartsattributessize100sortdate_get.activitypartsattributessize100sortdate_get...
# 🚀 Making get request to https://domo-community.domo.com/api/search/v1/activity
# Headers: {'accept': 'application/json, text/plain, */*', 'content-type': 'application/json;charset=utf-8', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {'parts': 'ATTRIBUTES', 'size': '100', 'sort': 'DATE'}
# Data: None
# JSON: None
#   Status: 200
# Running test function activitypartsattributessize100sortdate_get.test_activitypartsattributessize100sortdate_get...
#   Result: 200
# Updated activitypartsattributessize100sortdate_get.py with test results
# Testing module adapters_get from ./EXPORT/demo/adapters_get.py...
# Testing adapters_get.adapters_get...
# 🚀 Making get request to https://domo-community.domo.com/api/federated/v1/config/adapters
# Headers: {'accept': 'application/json, text/plain, */*', 'content-type': 'application/json;charset=utf-8', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {}
# Data: None
# JSON: None
#   Status: 200
# Running test function adapters_get.test_adapters_get...
#   Result: 200
# Updated adapters_get.py with test results
# Testing module athena_federated_get from ./EXPORT/demo/athena_federated_get.py...
# Testing athena_federated_get.athena_federated_get...
# 🚀 Making get request to https://domo-community.domo.com/api/data/v1/accounts/provider/athena-federated
# Headers: {'accept': 'application/json, text/plain, */*', 'content-type': 'application/json;charset=utf-8', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {}
# Data: None
# JSON: None
#   Status: 200
# Running test function athena_federated_get.test_athena_federated_get...
#   Result: 200
# Updated athena_federated_get.py with test results
# Testing module authenticate_post from ./EXPORT/demo/authenticate_post.py...
# Testing authenticate_post.authenticate_post...
# 🚀 Making post request to https://domo-community.domo.com/api/socket/v1/pusher/authenticate
# Headers: {'accept': '*/*', 'content-type': 'application/x-www-form-urlencoded', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {}
# Data: None
# JSON: None
#   Status: 400
# Running test function authenticate_post.test_authenticate_post...
#   Error: Expected status code 200, got {response.status_code}
# Updated authenticate_post.py with test results
# Testing module authorities_get from ./EXPORT/demo/authorities_get.py...
# Testing authorities_get.authorities_get...
# 🚀 Making get request to https://domo-community.domo.com/api/authorization/v1/authorities
# Headers: {'accept': 'application/json, text/plain, */*', 'content-type': 'application/json;charset=utf-8', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {}
# Data: None
# JSON: None
#   Status: 200
# Running test function authorities_get.test_authorities_get...
#   Result: 200
# Updated authorities_get.py with test results
# Testing module azure_federated_get from ./EXPORT/demo/azure_federated_get.py...
# Testing azure_federated_get.azure_federated_get...
# 🚀 Making get request to https://domo-community.domo.com/api/data/v1/accounts/provider/azure-federated
# Headers: {'accept': 'application/json, text/plain, */*', 'content-type': 'application/json;charset=utf-8', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {}
# Data: None
# JSON: None
#   Status: 200
# Running test function azure_federated_get.test_azure_federated_get...
#   Result: 200
# Updated azure_federated_get.py with test results
# Testing module bigquery_federated_get from ./EXPORT/demo/bigquery_federated_get.py...
# Testing bigquery_federated_get.bigquery_federated_get...
# 🚀 Making get request to https://domo-community.domo.com/api/data/v1/accounts/provider/bigquery-federated
# Headers: {'accept': 'application/json, text/plain, */*', 'content-type': 'application/json;charset=utf-8', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {}
# Data: None
# JSON: None
#   Status: 200
# Running test function bigquery_federated_get.test_bigquery_federated_get...
#   Result: 200
# Updated bigquery_federated_get.py with test results
# Testing module bigquery_federated_oauth_get from ./EXPORT/demo/bigquery_federated_oauth_get.py...
# Testing bigquery_federated_oauth_get.bigquery_federated_oauth_get...
# 🚀 Making get request to https://domo-community.domo.com/api/data/v1/accounts/provider/bigquery-federated-oauth
# Headers: {'accept': 'application/json, text/plain, */*', 'content-type': 'application/json;charset=utf-8', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {}
# Data: None
# JSON: None
#   Status: 200
# Running test function bigquery_federated_oauth_get.test_bigquery_federated_oauth_get...
#   Result: 200
# Updated bigquery_federated_oauth_get.py with test results
# Testing module bulkincludeprivatetrueincludealldetailstrue_post from ./EXPORT/demo/bulkincludeprivatetrueincludealldetailstrue_post.py...
# Testing bulkincludeprivatetrueincludealldetailstrue_post.bulkincludeprivatetrueincludealldetailstrue_post...
# 🚀 Making post request to https://domo-community.domo.com/api/data/v3/datasources/bulk
# Headers: {'accept': 'application/json, text/plain, */*', 'content-type': 'application/json;charset=utf-8', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {'includeprivate': 'true', 'includealldetails': 'true'}
# Data: None
# JSON: None
#   Status: 400
# Running test function bulkincludeprivatetrueincludealldetailstrue_post.test_bulkincludeprivatetrueincludealldetailstrue_post...
#   Error: Expected status code 200, got {response.status_code}
# Updated bulkincludeprivatetrueincludealldetailstrue_post.py with test results
# Testing module clickdata_post from ./EXPORT/demo/clickdata_post.py...
# Testing clickdata_post.clickdata_post...
# 🚀 Making post request to https://domo-community.domo.com/api/search/v1/clickData
# Headers: {'accept': '*/*', 'content-type': 'application/json', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {}
# Data: None
# JSON: {'queryProfile': 'DATA_CENTER', 'type': 'dataset', 'entityId': '1674a436-2f80-4abd-8191-d84634b41702', 'queryUuid': '279edcba-4bd6-49d6-a7cd-e2c681989950', 'winnerText': 'MONIT_Dataflow_Tiles_Exploded', 'position': 2}
#   Status: 200
# Running test function clickdata_post.test_clickdata_post...
#   Result: 200
# Updated clickdata_post.py with test results
# Testing module clog_post from ./EXPORT/demo/clog_post.py...
# Testing clog_post.clog_post...
# 🚀 Making post request to https://domo-community.domo.com/api/content/v1/stats/clog
# Headers: {'accept': '*/*', 'content-type': 'application/json', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {}
# Data: None
# JSON: {'behavior_name': 'route_time_taken', 'host': 'domo-community.domo.com', 'path': '/home', 'hash': '', 'genericizedPath': '/home', 'duration': 82904, 'firstClick': 1638, 'isFirstRoute': False, 'digestCycles': {'count': 6, 'min': 0, 'avg': 1, 'max': 3, 'sum': 3}, 'httpRequests': 0, 'failedAjaxRequests': 0, 'client': 'desktopwebapp', 'routeFinished': False, 'timeSinceRefresh': 690882, 'userAgent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/135.0.0.0 Safari/537.36', 'usedJSHeapSize': 225665691}
#   Status: 200
# Running test function clog_post.test_clog_post...
#   Result: 200
# Updated clog_post.py with test results
# Testing module configfeaturedatacenter_1674a436_2f80_4abd_8191_d84634b41702_get from ./EXPORT/demo/configfeaturedatacenter_1674a436_2f80_4abd_8191_d84634b41702_get.py...
# Testing configfeaturedatacenter_1674a436_2f80_4abd_8191_d84634b41702_get.configfeaturedatacenter_1674a436_2f80_4abd_8191_d84634b41702_get...
# 🚀 Making get request to https://domo-community.domo.com/api/socket/v1/pusher/config
# Headers: {'accept': 'application/json, text/plain, */*', 'content-type': 'application/json;charset=utf-8', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {'feature': 'datacenter-1674a436-2f80-4abd-8191-d84634b41702'}
# Data: None
# JSON: None
#   Status: 200
# Running test function configfeaturedatacenter_1674a436_2f80_4abd_8191_d84634b41702_get.test_configfeaturedatacenter_1674a436_2f80_4abd_8191_d84634b41702_get...
#   Result: 200
# Updated configfeaturedatacenter_1674a436_2f80_4abd_8191_d84634b41702_get.py with test results
# Testing module counts_put from ./EXPORT/demo/counts_put.py...
# Testing counts_put.counts_put...
# 🚀 Making put request to https://domo-community.domo.com/api/content/v1/analytics/views/cards/counts
# Headers: {'accept': 'application/json, text/plain, */*', 'content-type': 'application/json;charset=utf-8', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {}
# Data: None
# JSON: {'urns': ['2135741495', '1651689392', '1068279501', '1903106935', '2060661232', '1497730917', '937553651', '616316641', '70839410', '2038142808', '1956049557', '819472105', '1971320468', '199639698', '794139589', '399462556', '889563388', '430305555', '69926733', '1402587682']}
#   Status: 200
# Running test function counts_put.test_counts_put...
#   Result: 200
# Updated counts_put.py with test results
# Testing module create_post from ./EXPORT/demo/create_post.py...
# Testing create_post.create_post...
# 🚀 Making post request to https://domo-community.domo.com/api/content/v1/guide/create
# Headers: {'accept': 'application/json, text/plain, */*', 'content-type': 'application/json;charset=utf-8', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {}
# Data: None
# JSON: None
#   Status: 400
# Running test function create_post.test_create_post...
#   Error: Expected status code 200, got {response.status_code}
# Updated create_post.py with test results
# Testing module db2_federated_get from ./EXPORT/demo/db2_federated_get.py...
# Testing db2_federated_get.db2_federated_get...
# 🚀 Making get request to https://domo-community.domo.com/api/data/v1/accounts/provider/db2-federated
# Headers: {'accept': 'application/json, text/plain, */*', 'content-type': 'application/json;charset=utf-8', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {}
# Data: None
# JSON: None
#   Status: 200
# Running test function db2_federated_get.test_db2_federated_get...
#   Result: 200
# Updated db2_federated_get.py with test results
# Testing module departmentlimit1000000offset0search_get from ./EXPORT/demo/departmentlimit1000000offset0search_get.py...
# Testing departmentlimit1000000offset0search_get.departmentlimit1000000offset0search_get...
# 🚀 Making get request to https://domo-community.domo.com/api/content/v2/users/attributeTypeahead/DEPARTMENT
# Headers: {'accept': 'application/json, text/plain, */*', 'content-type': 'application/json;charset=utf-8', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {'limit': '1000000', 'offset': '0', 'search': ''}
# Data: None
# JSON: None
#   Status: 200
# Running test function departmentlimit1000000offset0search_get.test_departmentlimit1000000offset0search_get...
#   Result: 200
# Updated departmentlimit1000000offset0search_get.py with test results
# Testing module domopolicymanaged_last_export_date_get from ./EXPORT/demo/domopolicymanaged_last_export_date_get.py...
# Testing domopolicymanaged_last_export_date_get.domopolicymanaged_last_export_date_get...
# 🚀 Making get request to https://domo-community.domo.com/api/customer/v1/properties/domo.policy.managed_last_export_date
# Headers: {'accept': 'application/json, text/plain, */*', 'content-type': 'application/json;charset=utf-8', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {}
# Data: None
# JSON: None
#   Status: 200
# Running test function domopolicymanaged_last_export_date_get.test_domopolicymanaged_last_export_date_get...
#   Result: 200
# Updated domopolicymanaged_last_export_date_get.py with test results
# Testing module domopolicymanaged_last_export_get from ./EXPORT/demo/domopolicymanaged_last_export_get.py...
# Testing domopolicymanaged_last_export_get.domopolicymanaged_last_export_get...
# 🚀 Making get request to https://domo-community.domo.com/api/customer/v1/properties/domo.policy.managed_last_export
# Headers: {'accept': 'application/json, text/plain, */*', 'content-type': 'application/json;charset=utf-8', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {}
# Data: None
# JSON: None
#   Status: 200
# Running test function domopolicymanaged_last_export_get.test_domopolicymanaged_last_export_get...
#   Result: 200
# Updated domopolicymanaged_last_export_get.py with test results
# Testing module domoweb_post from ./EXPORT/demo/domoweb_post.py...
# Testing domoweb_post.domoweb_post...
# 🚀 Making post request to https://domo-community.domo.com/api/analytics/v1/domoweb
# Headers: {'accept': 'application/json, text/plain, */*', 'content-type': 'application/json;charset=utf-8', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {}
# Data: None
# JSON: None
#   Status: 400
# Running test function domoweb_post.test_domoweb_post...
#   Error: Expected status code 200, got {response.status_code}
# Updated domoweb_post.py with test results
# Testing module free_invite_get from ./EXPORT/demo/free_invite_get.py...
# Testing free_invite_get.free_invite_get...
# 🚀 Making get request to https://domo-community.domo.com/api/content/v3/customers/mmmm-0012-0200/features/free-invite
# Headers: {'accept': 'application/json, text/plain, */*', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {}
# Data: None
# JSON: None
#   Status: 200
# Running test function free_invite_get.test_free_invite_get...
#   Result: 200
# Updated free_invite_get.py with test results
# Testing module getignorecachefalseincludeactivefalseincludeusersfalse_post from ./EXPORT/demo/getignorecachefalseincludeactivefalseincludeusersfalse_post.py...
# Testing getignorecachefalseincludeactivefalseincludeusersfalse_post.getignorecachefalseincludeactivefalseincludeusersfalse_post...
# 🚀 Making post request to https://domo-community.domo.com/api/content/v2/groups/get
# Headers: {'accept': 'application/json, text/plain, */*', 'content-type': 'application/json;charset=utf-8', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {'ignorecache': 'false', 'includeactive': 'false', 'includeusers': 'false'}
# Data: None
# JSON: None
#   Status: 400
# Running test function getignorecachefalseincludeactivefalseincludeusersfalse_post.test_getignorecachefalseincludeactivefalseincludeusersfalse_post...
#   Error: Expected status code 200, got {response.status_code}
# Updated getignorecachefalseincludeactivefalseincludeusersfalse_post.py with test results
# Testing module get_0f7e7731_67ac_431c_b01d_e9ec4da59b7a from ./EXPORT/demo/get_0f7e7731_67ac_431c_b01d_e9ec4da59b7a.py...
# Testing get_0f7e7731_67ac_431c_b01d_e9ec4da59b7a.get_0f7e7731_67ac_431c_b01d_e9ec4da59b7a...
# 🚀 Making get request to https://domo-community.domo.com/api/codeengine/v2/packages/0f7e7731-67ac-431c-b01d-e9ec4da59b7a
# Headers: {'accept': 'application/json, text/plain, */*', 'content-type': 'application/json;charset=utf-8', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {'parts': 'versions'}
# Data: None
# JSON: None
#   Status: 200
# Running test function get_0f7e7731_67ac_431c_b01d_e9ec4da59b7a.test_get_0f7e7731_67ac_431c_b01d_e9ec4da59b7a...
#   Result: 200
# Updated get_0f7e7731_67ac_431c_b01d_e9ec4da59b7a.py with test results
# Testing module get_102 from ./EXPORT/demo/get_102.py...
# Testing get_102.get_102...
# 🚀 Making get request to https://domo-community.domo.com/api/codeengine/v2/packages/0f7e7731-67ac-431c-b01d-e9ec4da59b7a/versions/1.0.2
# Headers: {'accept': 'application/json, text/plain, */*', 'content-type': 'application/json;charset=utf-8', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {'parts': 'functions,code'}
# Data: None
# JSON: None
#   Status: 200
# Running test function get_102.test_get_102...
#   Result: 200
# Updated get_102.py with test results
# Testing module get_1477 from ./EXPORT/demo/get_1477.py...
# Testing get_1477.get_1477...
# 🚀 Making get request to https://domo-community.domo.com/api/data/v1/streams/1477
# Headers: {'accept': 'application/json, text/plain, */*', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {'fields': 'all'}
# Data: None
# JSON: None
#   Status: 200
# Running test function get_1477.test_get_1477...
#   Result: 200
# Updated get_1477.py with test results
# Testing module get_153795447 from ./EXPORT/demo/get_153795447.py...
# Testing get_153795447.get_153795447...
# 🚀 Making get request to https://domo-community.domo.com/api/content/v1/avatar/GROUP/153795447
# Headers: {'accept': '*/*', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {'size': '100', 'defaultbackground': '555555', 'defaultforeground': 'EEEEEE', 'defaulttext': 'GD'}
# Data: None
# JSON: None
#   Status: 200
# Running test function get_153795447.test_get_153795447...
#   Result: 200
# Updated get_153795447.py with test results
# Testing module get_1893952720 from ./EXPORT/demo/get_1893952720.py...
# Testing get_1893952720.get_1893952720...
# 🚀 Making get request to https://domo-community.domo.com/api/content/v1/avatar/USER/1893952720
# Headers: {'accept': '*/*', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {'size': '100', 'cachebuster': '1744085287320'}
# Data: None
# JSON: None
#   Status: 200
# Running test function get_1893952720.test_get_1893952720...
#   Result: 200
# Updated get_1893952720.py with test results
# Testing module get_1950208331 from ./EXPORT/demo/get_1950208331.py...
# Testing get_1950208331.get_1950208331...
# 🚀 Making get request to https://domo-community.domo.com/api/content/v1/landings/1950208331
# Headers: {'accept': 'application/json, text/plain, */*', 'content-type': 'application/json;charset=utf-8', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {}
# Data: None
# JSON: None
#   Status: 200
# Running test function get_1950208331.test_get_1950208331...
#   Result: 200
# Updated get_1950208331.py with test results
# Testing module get_2097317660 from ./EXPORT/demo/get_2097317660.py...
# Testing get_2097317660.get_2097317660...
# 🚀 Making get request to https://domo-community.domo.com/api/authorization/v1/roles/2097317660
# Headers: {'accept': 'application/json, text/plain, */*', 'content-type': 'application/json;charset=utf-8', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {}
# Data: None
# JSON: None
#   Status: 200
# Running test function get_2097317660.test_get_2097317660...
#   Result: 200
# Updated get_2097317660.py with test results
# Testing module get_2139745814 from ./EXPORT/demo/get_2139745814.py...
# Testing get_2139745814.get_2139745814...
# 🚀 Making get request to https://domo-community.domo.com/api/content/v2/groups/2139745814
# Headers: {'accept': 'application/json, text/plain, */*', 'content-type': 'application/json;charset=utf-8', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {}
# Data: None
# JSON: None
#   Status: 200
# Running test function get_2139745814.test_get_2139745814...
#   Result: 200
# Updated get_2139745814.py with test results
# Testing module get_7d351ba5_998b_453e_87a0_04eeff44e135 from ./EXPORT/demo/get_7d351ba5_998b_453e_87a0_04eeff44e135.py...
# Testing get_7d351ba5_998b_453e_87a0_04eeff44e135.get_7d351ba5_998b_453e_87a0_04eeff44e135...
# 🚀 Making get request to https://domo-community.domo.com/api/data/v3/datasources/7d351ba5-998b-453e-87a0-04eeff44e135
# Headers: {'accept': 'application/json, text/plain, */*', 'content-type': 'application/json;charset=utf-8', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {}
# Data: None
# JSON: None
#   Status: 200
# Running test function get_7d351ba5_998b_453e_87a0_04eeff44e135.test_get_7d351ba5_998b_453e_87a0_04eeff44e135...
#   Result: 200
# Updated get_7d351ba5_998b_453e_87a0_04eeff44e135.py with test results
# Testing module get_84658e41_924e_499c_987b_f82dc10163cc from ./EXPORT/demo/get_84658e41_924e_499c_987b_f82dc10163cc.py...
# Testing get_84658e41_924e_499c_987b_f82dc10163cc.get_84658e41_924e_499c_987b_f82dc10163cc...
# 🚀 Making get request to https://domo-community.domo.com/api/ai/readiness/v1/data-dictionary/dataset/84658e41-924e-499c-987b-f82dc10163cc
# Headers: {'accept': 'application/json, text/plain, */*', 'content-type': 'application/json;charset=utf-8', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {}
# Data: None
# JSON: None
#   Status: 200
# Running test function get_84658e41_924e_499c_987b_f82dc10163cc.test_get_84658e41_924e_499c_987b_f82dc10163cc...
#   Result: 200
# Updated get_84658e41_924e_499c_987b_f82dc10163cc.py with test results
# Testing module get_activity from ./EXPORT/demo/get_activity.py...
# Testing get_activity.get_activity...
# 🚀 Making get request to https://domo-community.domo.com/api/search/v1/activity
# Headers: {'accept': 'application/json, text/plain, */*', 'content-type': 'application/json;charset=utf-8', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {'parts': 'ATTRIBUTES', 'size': '100', 'sort': 'DATE'}
# Data: None
# JSON: None
#   Status: 200
# Running test function get_activity.test_get_activity...
#   Result: 200
# Updated get_activity.py with test results
# Testing module get_adapters from ./EXPORT/demo/get_adapters.py...
# Testing get_adapters.get_adapters...
# 🚀 Making get request to https://domo-community.domo.com/api/federated/v1/config/adapters
# Headers: {'accept': 'application/json, text/plain, */*', 'content-type': 'application/json;charset=utf-8', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {}
# Data: None
# JSON: None
#   Status: 200
# Running test function get_adapters.test_get_adapters...
#   Result: 200
# Updated get_adapters.py with test results
# Testing module get_athena_federated from ./EXPORT/demo/get_athena_federated.py...
# Testing get_athena_federated.get_athena_federated...
# 🚀 Making get request to https://domo-community.domo.com/api/data/v1/accounts/provider/athena-federated
# Headers: {'accept': 'application/json, text/plain, */*', 'content-type': 'application/json;charset=utf-8', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {}
# Data: None
# JSON: None
#   Status: 200
# Running test function get_athena_federated.test_get_athena_federated...
#   Result: 200
# Updated get_athena_federated.py with test results
# Testing module get_authorities from ./EXPORT/demo/get_authorities.py...
# Testing get_authorities.get_authorities...
# 🚀 Making get request to https://domo-community.domo.com/api/authorization/v1/authorities
# Headers: {'accept': 'application/json, text/plain, */*', 'content-type': 'application/json;charset=utf-8', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {}
# Data: None
# JSON: None
#   Status: 200
# Running test function get_authorities.test_get_authorities...
#   Result: 200
# Updated get_authorities.py with test results
# Testing module get_azure_federated from ./EXPORT/demo/get_azure_federated.py...
# Testing get_azure_federated.get_azure_federated...
# 🚀 Making get request to https://domo-community.domo.com/api/data/v1/accounts/provider/azure-federated
# Headers: {'accept': 'application/json, text/plain, */*', 'content-type': 'application/json;charset=utf-8', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {}
# Data: None
# JSON: None
#   Status: 200
# Running test function get_azure_federated.test_get_azure_federated...
#   Result: 200
# Updated get_azure_federated.py with test results
# Testing module get_bigquery_federated from ./EXPORT/demo/get_bigquery_federated.py...
# Testing get_bigquery_federated.get_bigquery_federated...
# 🚀 Making get request to https://domo-community.domo.com/api/data/v1/accounts/provider/bigquery-federated
# Headers: {'accept': 'application/json, text/plain, */*', 'content-type': 'application/json;charset=utf-8', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {}
# Data: None
# JSON: None
#   Status: 200
# Running test function get_bigquery_federated.test_get_bigquery_federated...
#   Result: 200
# Updated get_bigquery_federated.py with test results
# Testing module get_bigquery_federated_oauth from ./EXPORT/demo/get_bigquery_federated_oauth.py...
# Testing get_bigquery_federated_oauth.get_bigquery_federated_oauth...
# 🚀 Making get request to https://domo-community.domo.com/api/data/v1/accounts/provider/bigquery-federated-oauth
# Headers: {'accept': 'application/json, text/plain, */*', 'content-type': 'application/json;charset=utf-8', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {}
# Data: None
# JSON: None
#   Status: 200
# Running test function get_bigquery_federated_oauth.test_get_bigquery_federated_oauth...
#   Result: 200
# Updated get_bigquery_federated_oauth.py with test results
# Testing module get_cards from ./EXPORT/demo/get_cards.py...
# Testing get_cards.get_cards...
# 🚀 Making get request to https://domo-community.domo.com/api/content/v1/cards
# Headers: {'accept': '*/*', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {'urns': 'undefined', 'parts': 'certification,datasources,dateInfo,drillPathURNs,library,metadata,metadataOverrides,owners,slicers,subscriptions', 'includefiltered': 'true'}
# Data: None
# JSON: None
#   Status: 400
# Running test function get_cards.test_get_cards...
#   Error: get_cards() got an unexpected keyword argument 'includeFiltered'
# Updated get_cards.py with test results
# Testing module get_companysettings from ./EXPORT/demo/get_companysettings.py...
# Testing get_companysettings.get_companysettings...
# 🚀 Making get request to https://domo-community.domo.com/companysettings
# Headers: {'accept': 'application/json, text/plain, */*', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {}
# Data: None
# JSON: None
#   Status: 200
# Running test function get_companysettings.test_get_companysettings...
#   Result: 200
# Updated get_companysettings.py with test results
# Testing module get_config from ./EXPORT/demo/get_config.py...
# Testing get_config.get_config...
# 🚀 Making get request to https://domo-community.domo.com/api/socket/v1/pusher/config
# Headers: {'accept': 'application/json, text/plain, */*', 'content-type': 'application/json;charset=utf-8', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {'feature': 'datacenter-7d351ba5-998b-453e-87a0-04eeff44e135'}
# Data: None
# JSON: None
#   Status: 200
# Running test function get_config.test_get_config...
#   Result: 200
# Updated get_config.py with test results
# Testing module get_db2_federated from ./EXPORT/demo/get_db2_federated.py...
# Testing get_db2_federated.get_db2_federated...
# 🚀 Making get request to https://domo-community.domo.com/api/data/v1/accounts/provider/db2-federated
# Headers: {'accept': 'application/json, text/plain, */*', 'content-type': 'application/json;charset=utf-8', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {}
# Data: None
# JSON: None
#   Status: 200
# Running test function get_db2_federated.test_get_db2_federated...
#   Result: 200
# Updated get_db2_federated.py with test results
# Testing module get_department from ./EXPORT/demo/get_department.py...
# Testing get_department.get_department...
# 🚀 Making get request to https://domo-community.domo.com/api/content/v2/users/attributeTypeahead/DEPARTMENT
# Headers: {'accept': 'application/json, text/plain, */*', 'content-type': 'application/json;charset=utf-8', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {'limit': '1000000', 'offset': '0', 'search': ''}
# Data: None
# JSON: None
#   Status: 200
# Running test function get_department.test_get_department...
#   Result: 200
# Updated get_department.py with test results
# Testing module get_domopolicymanaged_last_export from ./EXPORT/demo/get_domopolicymanaged_last_export.py...
# Testing get_domopolicymanaged_last_export.get_domopolicymanaged_last_export...
# 🚀 Making get request to https://domo-community.domo.com/api/customer/v1/properties/domo.policy.managed_last_export
# Headers: {'accept': 'application/json, text/plain, */*', 'content-type': 'application/json;charset=utf-8', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {}
# Data: None
# JSON: None
#   Status: 200
# Running test function get_domopolicymanaged_last_export.test_get_domopolicymanaged_last_export...
#   Result: 200
# Updated get_domopolicymanaged_last_export.py with test results
# Testing module get_domopolicymanaged_last_export_date from ./EXPORT/demo/get_domopolicymanaged_last_export_date.py...
# Testing get_domopolicymanaged_last_export_date.get_domopolicymanaged_last_export_date...
# 🚀 Making get request to https://domo-community.domo.com/api/customer/v1/properties/domo.policy.managed_last_export_date
# Headers: {'accept': 'application/json, text/plain, */*', 'content-type': 'application/json;charset=utf-8', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {}
# Data: None
# JSON: None
#   Status: 200
# Running test function get_domopolicymanaged_last_export_date.test_get_domopolicymanaged_last_export_date...
#   Result: 200
# Updated get_domopolicymanaged_last_export_date.py with test results
# Testing module get_free_invite from ./EXPORT/demo/get_free_invite.py...
# Testing get_free_invite.get_free_invite...
# 🚀 Making get request to https://domo-community.domo.com/api/content/v3/customers/mmmm-0012-0200/features/free-invite
# Headers: {'accept': 'application/json, text/plain, */*', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {}
# Data: None
# JSON: None
#   Status: 200
# Running test function get_free_invite.test_get_free_invite...
#   Result: 200
# Updated get_free_invite.py with test results
# Testing module get_hana_federated from ./EXPORT/demo/get_hana_federated.py...
# Testing get_hana_federated.get_hana_federated...
# 🚀 Making get request to https://domo-community.domo.com/api/data/v1/accounts/provider/hana-federated
# Headers: {'accept': 'application/json, text/plain, */*', 'content-type': 'application/json;charset=utf-8', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {}
# Data: None
# JSON: None
#   Status: 200
# Running test function get_hana_federated.test_get_hana_federated...
#   Result: 200
# Updated get_hana_federated.py with test results
# Testing module get_index from ./EXPORT/demo/get_index.py...
# Testing get_index.get_index...
# 🚀 Making get request to https://domo-community.domo.com/users/index
# Headers: {'accept': '*/*', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {'cvuserids': '1950208331'}
# Data: None
# JSON: None
#   Status: 400
# Running test function get_index.test_get_index...
#   Error: Expected status code 200, got {response.status_code}
# Updated get_index.py with test results
# Testing module get_indexed from ./EXPORT/demo/get_indexed.py...
# Testing get_indexed.get_indexed...
# 🚀 Making get request to https://domo-community.domo.com/api/query/v1/datasources/7d351ba5-998b-453e-87a0-04eeff44e135/schema/indexed
# Headers: {'accept': 'application/json, text/plain, */*', 'content-type': 'application/json;charset=utf-8', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {'includehidden': 'true'}
# Data: None
# JSON: None
#   Status: 404
# Running test function get_indexed.test_get_indexed...
#   Error: Expected status code 200, got {response.status_code}
# Updated get_indexed.py with test results
# Testing module get_keys from ./EXPORT/demo/get_keys.py...
# Testing get_keys.get_keys...
# 🚀 Making get request to https://domo-community.domo.com/api/user/v1/properties/meta/keys
# Headers: {'accept': 'application/json, text/plain, */*', 'content-type': 'application/json;charset=utf-8', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {'keyspaces': 'customer-defined'}
# Data: None
# JSON: None
#   Status: 200
# Running test function get_keys.test_get_keys...
#   Result: 200
# Updated get_keys.py with test results
# Testing module get_model from ./EXPORT/demo/get_model.py...
# Testing get_model.get_model...
# 🚀 Making get request to https://domo-community.domo.com/api/dataprocessing/v1/ml/7d351ba5-998b-453e-87a0-04eeff44e135/model
# Headers: {'accept': 'application/json, text/plain, */*', 'content-type': 'application/json;charset=utf-8', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {}
# Data: None
# JSON: None
#   Status: 200
# Running test function get_model.test_get_model...
#   Result: 200
# Updated get_model.py with test results
# Testing module get_mysql_federated from ./EXPORT/demo/get_mysql_federated.py...
# Testing get_mysql_federated.get_mysql_federated...
# 🚀 Making get request to https://domo-community.domo.com/api/data/v1/accounts/provider/mysql-federated
# Headers: {'accept': 'application/json, text/plain, */*', 'content-type': 'application/json;charset=utf-8', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {}
# Data: None
# JSON: None
#   Status: 200
# Running test function get_mysql_federated.test_get_mysql_federated...
#   Result: 200
# Updated get_mysql_federated.py with test results
# Testing module get_nocompute from ./EXPORT/demo/get_nocompute.py...
# Testing get_nocompute.get_nocompute...
# 🚀 Making get request to https://domo-community.domo.com/api/data/v1/impacts/DATA_SOURCE/7d351ba5-998b-453e-87a0-04eeff44e135/nocompute
# Headers: {'accept': '*/*', 'content-type': 'application/json', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {}
# Data: None
# JSON: None
#   Status: 404
# Running test function get_nocompute.test_get_nocompute...
#   Error: Expected status code 200, got {response.status_code}
# Updated get_nocompute.py with test results
# Testing module get_oracle_federated from ./EXPORT/demo/get_oracle_federated.py...
# Testing get_oracle_federated.get_oracle_federated...
# 🚀 Making get request to https://domo-community.domo.com/api/data/v1/accounts/provider/oracle-federated
# Headers: {'accept': 'application/json, text/plain, */*', 'content-type': 'application/json;charset=utf-8', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {}
# Data: None
# JSON: None
#   Status: 200
# Running test function get_oracle_federated.test_get_oracle_federated...
#   Result: 200
# Updated get_oracle_federated.py with test results
# Testing module get_permissions from ./EXPORT/demo/get_permissions.py...
# Testing get_permissions.get_permissions...
# 🚀 Making get request to https://domo-community.domo.com/api/codeengine/v2/packages/0f7e7731-67ac-431c-b01d-e9ec4da59b7a/permissions
# Headers: {'accept': 'application/json, text/plain, */*', 'content-type': 'application/json;charset=utf-8', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {}
# Data: None
# JSON: None
#   Status: 200
# Running test function get_permissions.test_get_permissions...
#   Result: 200
# Updated get_permissions.py with test results
# Testing module get_postgres_federated from ./EXPORT/demo/get_postgres_federated.py...
# Testing get_postgres_federated.get_postgres_federated...
# 🚀 Making get request to https://domo-community.domo.com/api/data/v1/accounts/provider/postgres-federated
# Headers: {'accept': 'application/json, text/plain, */*', 'content-type': 'application/json;charset=utf-8', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {}
# Data: None
# JSON: None
#   Status: 200
# Running test function get_postgres_federated.test_get_postgres_federated...
#   Result: 200
# Updated get_postgres_federated.py with test results
# Testing module get_presto_federated from ./EXPORT/demo/get_presto_federated.py...
# Testing get_presto_federated.get_presto_federated...
# 🚀 Making get request to https://domo-community.domo.com/api/data/v1/accounts/provider/presto-federated
# Headers: {'accept': 'application/json, text/plain, */*', 'content-type': 'application/json;charset=utf-8', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {}
# Data: None
# JSON: None
#   Status: 200
# Running test function get_presto_federated.test_get_presto_federated...
#   Result: 200
# Updated get_presto_federated.py with test results
# Testing module get_profiles from ./EXPORT/demo/get_profiles.py...
# Testing get_profiles.get_profiles...
# 🚀 Making get request to https://domo-community.domo.com/api/content/v2/users/1950208331/profiles
# Headers: {'accept': 'application/json, text/plain, */*', 'content-type': 'application/json;charset=utf-8', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {}
# Data: None
# JSON: None
#   Status: 200
# Running test function get_profiles.test_get_profiles...
#   Result: 200
# Updated get_profiles.py with test results
# Testing module get_providers from ./EXPORT/demo/get_providers.py...
# Testing get_providers.get_providers...
# 🚀 Making get request to https://domo-community.domo.com/api/federated/v1/config/providers
# Headers: {'accept': 'application/json, text/plain, */*', 'content-type': 'application/json;charset=utf-8', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {}
# Data: None
# JSON: None
#   Status: 200
# Running test function get_providers.test_get_providers...
#   Result: 200
# Updated get_providers.py with test results
# Testing module get_redshift_federated from ./EXPORT/demo/get_redshift_federated.py...
# Testing get_redshift_federated.get_redshift_federated...
# 🚀 Making get request to https://domo-community.domo.com/api/data/v1/accounts/provider/redshift-federated
# Headers: {'accept': 'application/json, text/plain, */*', 'content-type': 'application/json;charset=utf-8', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {}
# Data: None
# JSON: None
#   Status: 200
# Running test function get_redshift_federated.test_get_redshift_federated...
#   Result: 200
# Updated get_redshift_federated.py with test results
# Testing module get_roles from ./EXPORT/demo/get_roles.py...
# Testing get_roles.get_roles...
# 🚀 Making get request to https://domo-community.domo.com/api/authorization/v1/roles
# Headers: {'accept': 'application/json, text/plain, */*', 'content-type': 'application/json;charset=utf-8', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {}
# Data: None
# JSON: None
#   Status: 200
# Running test function get_roles.test_get_roles...
#   Result: 200
# Updated get_roles.py with test results
# Testing module get_saved from ./EXPORT/demo/get_saved.py...
# Testing get_saved.get_saved...
# 🚀 Making get request to https://domo-community.domo.com/api/search/v1/saved
# Headers: {'accept': '*/*', 'content-type': 'application/json', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {'queryprofile': 'datacenter'}
# Data: None
# JSON: None
#   Status: 200
# Running test function get_saved.test_get_saved...
#   Result: 200
# Updated get_saved.py with test results
# Testing module get_snowflake_federated from ./EXPORT/demo/get_snowflake_federated.py...
# Testing get_snowflake_federated.get_snowflake_federated...
# 🚀 Making get request to https://domo-community.domo.com/api/data/v1/accounts/provider/snowflake-federated
# Headers: {'accept': 'application/json, text/plain, */*', 'content-type': 'application/json;charset=utf-8', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {}
# Data: None
# JSON: None
#   Status: 200
# Running test function get_snowflake_federated.test_get_snowflake_federated...
#   Result: 200
# Updated get_snowflake_federated.py with test results
# Testing module get_snowflake_federated_keypair from ./EXPORT/demo/get_snowflake_federated_keypair.py...
# Testing get_snowflake_federated_keypair.get_snowflake_federated_keypair...
# 🚀 Making get request to https://domo-community.domo.com/api/data/v1/accounts/provider/snowflake-federated-keypair
# ...
# Updated put_84658e41_924e_499c_987b_f82dc10163cc.py with test results
# Testing module put_counts from ./EXPORT/demo/put_counts.py...
# Testing put_counts.put_counts...
# 🚀 Making put request to https://domo-community.domo.com/api/content/v1/analytics/views/cards/counts
# Headers: {'accept': 'application/json, text/plain, */*', 'content-type': 'application/json;charset=utf-8', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {}
# Data: None
# JSON: {'urns': ['2135741495', '1651689392', '1068279501', '1903106935', '2060661232', '1497730917', '937553651', '616316641', '70839410', '2038142808', '1956049557', '819472105', '1971320468', '199639698', '794139589', '399462556', '889563388', '430305555', '69926733', '1402587682']}
#   Status: 200
# Running test function put_counts.test_put_counts...
#   Result: 200
# Updated put_counts.py with test results
# Testing module put_render from ./EXPORT/demo/put_render.py...
# Testing put_render.put_render...
# 🚀 Making put request to https://domo-community.domo.com/api/content/v1/cards/kpi/2135741495/render
# Headers: {'accept': 'application/json, text/plain, */*', 'content-type': 'application/json;charset=utf-8', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {'parts': 'image'}
# Data: None
# JSON: {'width': 50, 'height': 50}
#   Status: 200
# Running test function put_render.test_put_render...
#   Result: 200
# Updated put_render.py with test results
# Testing module query_post from ./EXPORT/demo/query_post.py...
# Testing query_post.query_post...
# 🚀 Making post request to https://domo-community.domo.com/api/search/v1/query
# Headers: {'accept': '*/*', 'content-type': 'application/json', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {}
# Data: None
# JSON: {'entities': ['DATASET'], 'count': 0, 'offset': 0, 'combineResults': False, 'query': '*', 'queryProfile': 'DATA_CENTER', 'filters': [{'filterType': 'term', 'field': 'owned_by_id', 'value': '1893952720:USER', 'name': 'Jae Wilson1', 'not': False}, {'filterType': 'term', 'field': 'dataprovidername_facet', 'value': 'Jupyter Data', 'name': 'Jupyter Data', 'not': False}], 'facetValuesToInclude': None, 'facetValueLimit': 400, 'facetValueOffset': 0, 'includePhonetic': True, 'useEntities': True}
#   Status: 200
# Running test function query_post.test_query_post...
#   Result: 200
# Updated query_post.py with test results
# Testing module redshift_federated_get from ./EXPORT/demo/redshift_federated_get.py...
# Testing redshift_federated_get.redshift_federated_get...
# 🚀 Making get request to https://domo-community.domo.com/api/data/v1/accounts/provider/redshift-federated
# Headers: {'accept': 'application/json, text/plain, */*', 'content-type': 'application/json;charset=utf-8', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {}
# Data: None
# JSON: None
#   Status: 200
# Running test function redshift_federated_get.test_redshift_federated_get...
#   Result: 200
# Updated redshift_federated_get.py with test results
# Testing module renderpartsimage_put from ./EXPORT/demo/renderpartsimage_put.py...
# Testing renderpartsimage_put.renderpartsimage_put...
# 🚀 Making put request to https://domo-community.domo.com/api/content/v1/cards/kpi/2135741495/render
# Headers: {'accept': 'application/json, text/plain, */*', 'content-type': 'application/json;charset=utf-8', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {'parts': 'image'}
# Data: None
# JSON: {'width': 50, 'height': 50}
#   Status: 200
# Running test function renderpartsimage_put.test_renderpartsimage_put...
#   Result: 200
# Updated renderpartsimage_put.py with test results
# Testing module roles_get from ./EXPORT/demo/roles_get.py...
# Testing roles_get.roles_get...
# 🚀 Making get request to https://domo-community.domo.com/api/authorization/v1/roles
# Headers: {'accept': 'application/json, text/plain, */*', 'content-type': 'application/json;charset=utf-8', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {}
# Data: None
# JSON: None
#   Status: 200
# Running test function roles_get.test_roles_get...
#   Result: 200
# Updated roles_get.py with test results
# Testing module savedqueryprofiledatacenter_get from ./EXPORT/demo/savedqueryprofiledatacenter_get.py...
# Testing savedqueryprofiledatacenter_get.savedqueryprofiledatacenter_get...
# 🚀 Making get request to https://domo-community.domo.com/api/search/v1/saved
# Headers: {'accept': '*/*', 'content-type': 'application/json', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {'queryprofile': 'datacenter'}
# Data: None
# JSON: None
#   Status: 200
# Running test function savedqueryprofiledatacenter_get.test_savedqueryprofiledatacenter_get...
#   Result: 200
# Updated savedqueryprofiledatacenter_get.py with test results
# Testing module searchexplainfalse_post from ./EXPORT/demo/searchexplainfalse_post.py...
# Testing searchexplainfalse_post.searchexplainfalse_post...
# 🚀 Making post request to https://domo-community.domo.com/api/identity/v1/users/search
# Headers: {'accept': 'application/json, text/plain, */*', 'content-type': 'application/json;charset=utf-8', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {'explain': 'false'}
# Data: None
# JSON: {'showCount': True, 'includeDeleted': False, 'onlyDeleted': False, 'includeSupport': False, 'limit': 200, 'offset': 0, 'sort': {'field': 'created', 'order': 'DESC'}, 'parts': ['MINIMAL'], 'attributes': ['id', 'displayName', 'isActive', 'roleId', 'department', 'title', 'emailAddress', 'phoneNumber', 'created']}
#   Status: 200
# Running test function searchexplainfalse_post.test_searchexplainfalse_post...
#   Result: 200
# Updated searchexplainfalse_post.py with test results
# Testing module search_post from ./EXPORT/demo/search_post.py...
# Testing search_post.search_post...
# 🚀 Making post request to https://domo-community.domo.com/api/query/v1/functions/search
# Headers: {'accept': 'application/json, text/plain, */*', 'content-type': 'application/json;charset=utf-8', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {}
# Data: None
# JSON: {'filters': [{'field': 'notvariable'}, {'field': 'status', 'value': True}, {'field': 'dataset', 'idList': ['1674a436-2f80-4abd-8191-d84634b41702']}], 'sort': {'field': 'name', 'ascending': True}, 'offset': 0, 'limit': 5000}
#   Status: 200
# Running test function search_post.test_search_post...
#   Result: 200
# Updated search_post.py with test results
# Testing module snowflake_federated_get from ./EXPORT/demo/snowflake_federated_get.py...
# Testing snowflake_federated_get.snowflake_federated_get...
# 🚀 Making get request to https://domo-community.domo.com/api/data/v1/accounts/provider/snowflake-federated
# Headers: {'accept': 'application/json, text/plain, */*', 'content-type': 'application/json;charset=utf-8', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {}
# Data: None
# JSON: None
#   Status: 200
# Running test function snowflake_federated_get.test_snowflake_federated_get...
#   Result: 200
# Updated snowflake_federated_get.py with test results
# Testing module snowflake_federated_keypair_get from ./EXPORT/demo/snowflake_federated_keypair_get.py...
# Testing snowflake_federated_keypair_get.snowflake_federated_keypair_get...
# 🚀 Making get request to https://domo-community.domo.com/api/data/v1/accounts/provider/snowflake-federated-keypair
# Headers: {'accept': 'application/json, text/plain, */*', 'content-type': 'application/json;charset=utf-8', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {}
# Data: None
# JSON: None
#   Status: 200
# Running test function snowflake_federated_keypair_get.test_snowflake_federated_keypair_get...
#   Result: 200
# Updated snowflake_federated_keypair_get.py with test results
# Testing module snowflake_federated_oauth_get from ./EXPORT/demo/snowflake_federated_oauth_get.py...
# Testing snowflake_federated_oauth_get.snowflake_federated_oauth_get...
# 🚀 Making get request to https://domo-community.domo.com/api/data/v1/accounts/provider/snowflake-federated-oauth
# Headers: {'accept': 'application/json, text/plain, */*', 'content-type': 'application/json;charset=utf-8', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {}
# Data: None
# JSON: None
#   Status: 200
# Running test function snowflake_federated_oauth_get.test_snowflake_federated_oauth_get...
#   Result: 200
# Updated snowflake_federated_oauth_get.py with test results
# Testing module sqlserver_federated_get from ./EXPORT/demo/sqlserver_federated_get.py...
# Testing sqlserver_federated_get.sqlserver_federated_get...
# 🚀 Making get request to https://domo-community.domo.com/api/data/v1/accounts/provider/sqlserver-federated
# Headers: {'accept': 'application/json, text/plain, */*', 'content-type': 'application/json;charset=utf-8', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {}
# Data: None
# JSON: None
#   Status: 200
# Running test function sqlserver_federated_get.test_sqlserver_federated_get...
#   Result: 200
# Updated sqlserver_federated_get.py with test results
# Testing module suggest_post from ./EXPORT/demo/suggest_post.py...
# Testing suggest_post.suggest_post...
# 🚀 Making post request to https://domo-community.domo.com/api/search/v1/suggest
# Headers: {'accept': 'application/json, text/plain, */*', 'content-type': 'application/json;charset=utf-8', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {}
# Data: None
# JSON: {'entities': [], 'query': '*', 'state': 'suggest', 'queryProfile': 'LEFT_NAV_SEARCH', 'count': 20}
#   Status: 200
# Running test function suggest_post.test_suggest_post...
#   Result: 200
# Updated suggest_post.py with test results
# Testing module teams_get from ./EXPORT/demo/teams_get.py...
# Testing teams_get.teams_get...
# 🚀 Making get request to https://domo-community.domo.com/api/content/v2/users/1950208331/teams
# Headers: {'accept': 'application/json, text/plain, */*', 'content-type': 'application/json;charset=utf-8', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {}
# Data: None
# JSON: None
#   Status: 200
# Running test function teams_get.test_teams_get...
#   Result: 200
# Updated teams_get.py with test results
# Testing module teradata_federated_get from ./EXPORT/demo/teradata_federated_get.py...
# Testing teradata_federated_get.teradata_federated_get...
# 🚀 Making get request to https://domo-community.domo.com/api/data/v1/accounts/provider/teradata-federated
# Headers: {'accept': 'application/json, text/plain, */*', 'content-type': 'application/json;charset=utf-8', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {}
# Data: None
# JSON: None
#   Status: 200
# Running test function teradata_federated_get.test_teradata_federated_get...
#   Result: 200
# Updated teradata_federated_get.py with test results
# Testing module titlelimit1000000offset0search_get from ./EXPORT/demo/titlelimit1000000offset0search_get.py...
# Testing titlelimit1000000offset0search_get.titlelimit1000000offset0search_get...
# 🚀 Making get request to https://domo-community.domo.com/api/content/v2/users/attributeTypeahead/TITLE
# Headers: {'accept': 'application/json, text/plain, */*', 'content-type': 'application/json;charset=utf-8', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {'limit': '1000000', 'offset': '0', 'search': ''}
# Data: None
# JSON: None
#   Status: 200
# Running test function titlelimit1000000offset0search_get.test_titlelimit1000000offset0search_get...
#   Result: 200
# Updated titlelimit1000000offset0search_get.py with test results
# Testing module trino_federated_get from ./EXPORT/demo/trino_federated_get.py...
# Testing trino_federated_get.trino_federated_get...
# 🚀 Making get request to https://domo-community.domo.com/api/data/v1/accounts/provider/trino-federated
# Headers: {'accept': 'application/json, text/plain, */*', 'content-type': 'application/json;charset=utf-8', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {}
# Data: None
# JSON: None
#   Status: 200
# Running test function trino_federated_get.test_trino_federated_get...
#   Result: 200
# Updated trino_federated_get.py with test results
# Testing module userroleiddefaultdefaultvalue2ignorecachetrue_get from ./EXPORT/demo/userroleiddefaultdefaultvalue2ignorecachetrue_get.py...
# Testing userroleiddefaultdefaultvalue2ignorecachetrue_get.userroleiddefaultdefaultvalue2ignorecachetrue_get...
# 🚀 Making get request to https://domo-community.domo.com/api/content/v1/customer-states/user.roleid.default
# Headers: {'accept': 'application/json, text/plain, */*', 'content-type': 'application/json;charset=utf-8', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {'defaultvalue': '2', 'ignorecache': 'true'}
# Data: None
# JSON: None
#   Status: 200
# Running test function userroleiddefaultdefaultvalue2ignorecachetrue_get.test_userroleiddefaultdefaultvalue2ignorecachetrue_get...
#   Result: 200
# Updated userroleiddefaultdefaultvalue2ignorecachetrue_get.py with test results
# Testing module userrolesallowlist_get from ./EXPORT/demo/userrolesallowlist_get.py...
# Testing userrolesallowlist_get.userrolesallowlist_get...
# 🚀 Making get request to https://domo-community.domo.com/api/customer/v1/properties/user.roles.allowlist
# Headers: {'accept': 'application/json, text/plain, */*', 'content-type': 'application/json;charset=utf-8', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {}
# Data: None
# JSON: None
#   Status: 200
# Running test function userrolesallowlist_get.test_userrolesallowlist_get...
#   Result: 200
# Updated userrolesallowlist_get.py with test results
# Testing module vertica_federated_get from ./EXPORT/demo/vertica_federated_get.py...
# Testing vertica_federated_get.vertica_federated_get...
# 🚀 Making get request to https://domo-community.domo.com/api/data/v1/accounts/provider/vertica-federated
# Headers: {'accept': 'application/json, text/plain, */*', 'content-type': 'application/json;charset=utf-8', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {}
# Data: None
# JSON: None
#   Status: 200
# Running test function vertica_federated_get.test_vertica_federated_get...
#   Result: 200
# Updated vertica_federated_get.py with test results
# Testing module watson_federated_get from ./EXPORT/demo/watson_federated_get.py...
# Testing watson_federated_get.watson_federated_get...
# 🚀 Making get request to https://domo-community.domo.com/api/data/v1/accounts/provider/watson-federated
# Headers: {'accept': 'application/json, text/plain, */*', 'content-type': 'application/json;charset=utf-8', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {}
# Data: None
# JSON: None
#   Status: 200
# Running test function watson_federated_get.test_watson_federated_get...
#   Result: 200
# Updated watson_federated_get.py with test results
#
# Test Summary: 220/276 successful
