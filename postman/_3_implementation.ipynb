# %% [markdown]
# # Postman Collection Converter
#
# This notebook demonstrates how to convert Postman collections to Python API client code using the PostmanCollectionConverter library.
#
#
# ```mermaid
# flowchart TD
#     A["Postman API"] --introduce consistency via modeling --> B["models.py"]
#     B -- integration benefits from consistent classes  --> C["converter.py"]
#     C  -- users appreciate classes with thought out methods --> D["implementation.ipynb"]
# ```

# %% [markdown]
# ## Class Flow
#
# ```mermaid
# flowchart TD
#     JSON["Postman Collection JSON"]
#
#     subgraph Parsing["API Modeling Phase"]
#         JSON -- from api / json --> Collection["PostmanCollection"]
#         Collection -- contains many --> Requests["PostmanRequest Objects"]
#     end
#
#     subgraph Converting["Conversion Phase"]
#         Requests -- Convert --> RequestConverter["PostmanRequestConverter"]
#         RequestConverter -- Generates -->  Code["Python function string"]
#         Code -- Write --> Files["export/files.py"]
#     end
#
#
# ```

# %%
import os

from _1_models import PostmanCollection
from _2_converter import PostmanCollectionConverter, PostmanRequestConverter
from _2_tester import test_exports
# Out:
#   Cell In[1], line 4
#     from 2_converter import PostmanCollectionConverter, PostmanRequestConverter
#           ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# ## Load a Postman Collection
#
# First, let's load a Postman collection from a JSON file.

# %%
# Replace this with your Postman collection path
collection_path = "demo.postman_collection.json"

# Define the output directory
output_dir = "./EXPORT/demo/"

# Load the collection from a file
collection = PostmanCollection.from_file(collection_path)
from pprint import pprint
# pprint(collection.info.__dict__)
# collection.list_all_params()


pprint(collection.requests[0].header)
# Out:
# [PostmanRequest_Header(key='host', value='domo-community.domo.com'),
#  PostmanRequest_Header(key='accept', value='*/*'),
#  PostmanRequest_Header(key='sec-ch-ua',
#                        value='"Chromium";v="134", "Not:A-Brand";v="24", '
#                              '"Google Chrome";v="134"'),
#  PostmanRequest_Header(key='user-agent',
#                        value='Mozilla/5.0 (Windows NT 10.0; Win64; x64) '
#                              'AppleWebKit/537.36 (KHTML, like Gecko) '
#                              'Chrome/134.0.0.0 Safari/537.36'),
#  PostmanRequest_Header(key='x-csrf-token',
#                        value='91789c42-2c60-47ec-b496-58f88e3e6b7f'),
#  PostmanRequest_Header(key='sec-fetch-dest', value='empty'),
#  PostmanRequest_Header(key='sec-fetch-mode', value='cors'),
#  PostmanRequest_Header(key='sec-fetch-site', value='same-origin'),
#  PostmanRequest_Header(key='x-requested-with', value='XMLHttpRequest'),
#  PostmanRequest_Header(key='sec-ch-ua-mobile', value='?0'),
#  PostmanRequest_Header(key='sec-ch-ua-platform', value='"Windows"'),
#  PostmanRequest_Header(key='x-domo-requestcontext',
#                        value='{"clientToe":"C5MAH5D893-AKRML"}')]

# %% [markdown]
# ## Customize the Conversion
#
# Let's define some customization options for specific functions.

# %%
# Define default headers to include in all requests
default_required_headers = ['accept', 'content-type']

# Customization options for specific endpoints
customizations = {
    # Function name -> customization options
    "get_cards": {
        "default_params": [ "parts", "includeFiltered"],
        "ignored_params" : ["urns", "includeFiltered"],
    }
}

# %% [markdown]
# ## Generate Python API Client Files
#
# Now let's generate the Python API client files from the Postman collection.

# %%
converter = PostmanCollectionConverter.from_postman_collection(
    postman_path=collection_path,
    export_folder=output_dir,
    customize=customizations,
    required_headers=default_required_headers  # Pass global required headers
)
# Out:
# Exported function to ./EXPORT/demo/get_cards.py
# Exported function to ./EXPORT/demo/get_domopolicymanaged_last_export.py
# Exported function to ./EXPORT/demo/post_search.py
# Exported function to ./EXPORT/demo/get_domopolicymanaged_last_export_date.py
# Exported function to ./EXPORT/demo/get_roles.py
# Exported function to ./EXPORT/demo/get_keys.py
# Exported function to ./EXPORT/demo/post_create.py
# Exported function to ./EXPORT/demo/post_domoweb.py
# Exported function to ./EXPORT/demo/get_index.py
# Exported function to ./EXPORT/demo/get_1950208331.py
# Exported function to ./EXPORT/demo/get_teams.py
# Exported function to ./EXPORT/demo/get_1950208331.py
# Exported function to ./EXPORT/demo/get_authorities.py
# Exported function to ./EXPORT/demo/post_search.py
# Exported function to ./EXPORT/demo/post_query.py
# Exported function to ./EXPORT/demo/get_saved.py
# Exported function to ./EXPORT/demo/get_config.py
# Exported function to ./EXPORT/demo/get_providers.py
# Exported function to ./EXPORT/demo/get_adapters.py
# Exported function to ./EXPORT/demo/post_authenticate.py
# Exported function to ./EXPORT/demo/get_athena_federated.py
# Exported function to ./EXPORT/demo/get_oracle_federated.py
# Exported function to ./EXPORT/demo/get_snowflake_federated.py
# Exported function to ./EXPORT/demo/get_snowflake_federated_keypair.py
# Exported function to ./EXPORT/demo/get_postgres_federated.py
# Exported function to ./EXPORT/demo/get_watson_federated.py
# Exported function to ./EXPORT/demo/get_teradata_federated.py
# Exported function to ./EXPORT/demo/get_azure_federated.py
# Exported function to ./EXPORT/demo/get_vertica_federated.py
# Exported function to ./EXPORT/demo/get_bigquery_federated.py
# Exported function to ./EXPORT/demo/get_presto_federated.py
# Exported function to ./EXPORT/demo/get_redshift_federated.py
# Exported function to ./EXPORT/demo/get_sqlserver_federated.py
# Exported function to ./EXPORT/demo/get_trino_federated.py
# Exported function to ./EXPORT/demo/get_db2_federated.py
# Exported function to ./EXPORT/demo/get_snowflake_federated_oauth.py
# Exported function to ./EXPORT/demo/get_bigquery_federated_oauth.py
# Exported function to ./EXPORT/demo/get_mysql_federated.py
# Exported function to ./EXPORT/demo/get_hana_federated.py
# Exported function to ./EXPORT/demo/get_providers.py
# Exported function to ./EXPORT/demo/get_0f7e7731_67ac_431c_b01d_e9ec4da59b7a.py
# Exported function to ./EXPORT/demo/get_permissions.py
# Exported function to ./EXPORT/demo/get_102.py
# Exported function to ./EXPORT/demo/post_clickdata.py
# Exported function to ./EXPORT/demo/get_1477.py
# Exported function to ./EXPORT/demo/get_1950208331.py
# Exported function to ./EXPORT/demo/post_bulk.py
# Exported function to ./EXPORT/demo/get_department.py
# Exported function to ./EXPORT/demo/get_permissions.py
# Exported function to ./EXPORT/demo/post_search.py
# Exported function to ./EXPORT/demo/get_snowflake_federated.py
# Exported function to ./EXPORT/demo/get_2097317660.py
# Exported function to ./EXPORT/demo/get_mysql_federated.py
# Exported function to ./EXPORT/demo/get_userrolesallowlist.py
# Exported function to ./EXPORT/demo/get_teams.py
# Exported function to ./EXPORT/demo/get_domopolicymanaged_last_export.py
# Exported function to ./EXPORT/demo/get_7d351ba5_998b_453e_87a0_04eeff44e135.py
# Exported function to ./EXPORT/demo/post_suggest.py
# Exported function to ./EXPORT/demo/put_counts.py
# Exported function to ./EXPORT/demo/get_domopolicymanaged_last_export_date.py
# Exported function to ./EXPORT/demo/get_roles.py
# Exported function to ./EXPORT/demo/get_oracle_federated.py
# Exported function to ./EXPORT/demo/get_1893952720.py
# Exported function to ./EXPORT/demo/put_render.py
# Exported function to ./EXPORT/demo/get_athena_federated.py
# Exported function to ./EXPORT/demo/get_nocompute.py
# Exported function to ./EXPORT/demo/get_0f7e7731_67ac_431c_b01d_e9ec4da59b7a.py
# Exported function to ./EXPORT/demo/get_providers.py
# Exported function to ./EXPORT/demo/put_84658e41_924e_499c_987b_f82dc10163cc.py
# Exported function to ./EXPORT/demo/get_presto_federated.py
# Exported function to ./EXPORT/demo/get_2139745814.py
# Exported function to ./EXPORT/demo/get_153795447.py
# Exported function to ./EXPORT/demo/get_postgres_federated.py
# Exported function to ./EXPORT/demo/get_userroleiddefault.py
# Exported function to ./EXPORT/demo/get_102.py
# Exported function to ./EXPORT/demo/get_7d351ba5_998b_453e_87a0_04eeff44e135.py
# Exported function to ./EXPORT/demo/get_redshift_federated.py
# Exported function to ./EXPORT/demo/get_watson_federated.py
# Exported function to ./EXPORT/demo/get_keys.py
# Exported function to ./EXPORT/demo/post_query.py
# Exported function to ./EXPORT/demo/post_search.py
# Exported function to ./EXPORT/demo/get_indexed.py
# Exported function to ./EXPORT/demo/post_84658e41_924e_499c_987b_f82dc10163cc.py
# Exported function to ./EXPORT/demo/post_get.py
# Exported function to ./EXPORT/demo/get_snowflake_federated_keypair.py
# Exported function to ./EXPORT/demo/post_domoweb.py
# Exported function to ./EXPORT/demo/get_free_invite.py
# Exported function to ./EXPORT/demo/get_azure_federated.py
# Exported function to ./EXPORT/demo/get_bigquery_federated_oauth.py
# Exported function to ./EXPORT/demo/get_trino_federated.py
# Exported function to ./EXPORT/demo/get_sqlserver_federated.py
# Exported function to ./EXPORT/demo/get_config.py
# Exported function to ./EXPORT/demo/get_84658e41_924e_499c_987b_f82dc10163cc.py
# Exported function to ./EXPORT/demo/get_1950208331.py
# Exported function to ./EXPORT/demo/get_adapters.py
# Exported function to ./EXPORT/demo/get_db2_federated.py
# Exported function to ./EXPORT/demo/post_search.py
# Exported function to ./EXPORT/demo/get_index.py
# Exported function to ./EXPORT/demo/get_hana_federated.py
# Exported function to ./EXPORT/demo/get_title.py
# Exported function to ./EXPORT/demo/get_activity.py
# Exported function to ./EXPORT/demo/get_teradata_federated.py
# Exported function to ./EXPORT/demo/post_access.py
# Exported function to ./EXPORT/demo/get_snowflake_federated_oauth.py
# Exported function to ./EXPORT/demo/get_authorities.py
# Exported function to ./EXPORT/demo/get_7d351ba5_998b_453e_87a0_04eeff44e135.py
# Exported function to ./EXPORT/demo/post_me.py
# Exported function to ./EXPORT/demo/get_vertica_federated.py
# Exported function to ./EXPORT/demo/get_companysettings.py
# Exported function to ./EXPORT/demo/post_list.py
# Exported function to ./EXPORT/demo/get_7d351ba5_998b_453e_87a0_04eeff44e135.py
# Exported function to ./EXPORT/demo/get_model.py
# Exported function to ./EXPORT/demo/post_clog.py
# Exported function to ./EXPORT/demo/get_bigquery_federated.py
# Exported function to ./EXPORT/demo/get_1950208331.py
# Exported function to ./EXPORT/demo/get_providers.py
# Exported function to ./EXPORT/demo/patch_1950208331.py
# Exported function to ./EXPORT/demo/post_authenticate.py
# Exported function to ./EXPORT/demo/get_profiles.py
# Exported function to ./EXPORT/demo/get_saved.py
# Exported function to ./EXPORT/demo/post_create.py
# Exported function to ./EXPORT/demo/get_users.py

# %% [markdown]
# ## Test the Generated API Client
#
# Now we can test our generated API client functions.

# %%
# Define auth credentials
auth = {
    "base_url": "https://domo-community.domo.com",
    "headers": {
        "x-domo-developer-token": os.environ["DOMO_ACCESS_TOKEN"],
        "base_url": f"https://{os.environ['domo_instance']}.domo.com",
    }
}



# Test the exported functions (commented out to avoid making actual API calls)
results = test_exports(
    export_folder=output_dir,
    auth=auth,
    debug_api=True,
    update_files=True
)
# Out:
# Testing module get_0f7e7731_67ac_431c_b01d_e9ec4da59b7a from ./EXPORT/demo/get_0f7e7731_67ac_431c_b01d_e9ec4da59b7a.py...
# Error loading module get_0f7e7731_67ac_431c_b01d_e9ec4da59b7a.py: invalid syntax (./EXPORT/demo/get_0f7e7731_67ac_431c_b01d_e9ec4da59b7a.py, line 6)
# Testing module get_102 from ./EXPORT/demo/get_102.py...
# Error loading module get_102.py: invalid syntax (./EXPORT/demo/get_102.py, line 6)
# Testing module get_1477 from ./EXPORT/demo/get_1477.py...
# Error loading module get_1477.py: invalid syntax (./EXPORT/demo/get_1477.py, line 6)
# Testing module get_153795447 from ./EXPORT/demo/get_153795447.py...
# Error loading module get_153795447.py: invalid syntax (./EXPORT/demo/get_153795447.py, line 6)
# Testing module get_1893952720 from ./EXPORT/demo/get_1893952720.py...
# Error loading module get_1893952720.py: invalid syntax (./EXPORT/demo/get_1893952720.py, line 6)
# Testing module get_1950208331 from ./EXPORT/demo/get_1950208331.py...
# Error loading module get_1950208331.py: invalid syntax (./EXPORT/demo/get_1950208331.py, line 6)
# Testing module get_2097317660 from ./EXPORT/demo/get_2097317660.py...
# Error loading module get_2097317660.py: invalid syntax (./EXPORT/demo/get_2097317660.py, line 6)
# Testing module get_2139745814 from ./EXPORT/demo/get_2139745814.py...
# Error loading module get_2139745814.py: invalid syntax (./EXPORT/demo/get_2139745814.py, line 6)
# Testing module get_7d351ba5_998b_453e_87a0_04eeff44e135 from ./EXPORT/demo/get_7d351ba5_998b_453e_87a0_04eeff44e135.py...
# Error loading module get_7d351ba5_998b_453e_87a0_04eeff44e135.py: invalid syntax (./EXPORT/demo/get_7d351ba5_998b_453e_87a0_04eeff44e135.py, line 6)
# Testing module get_84658e41_924e_499c_987b_f82dc10163cc from ./EXPORT/demo/get_84658e41_924e_499c_987b_f82dc10163cc.py...
# Error loading module get_84658e41_924e_499c_987b_f82dc10163cc.py: invalid syntax (./EXPORT/demo/get_84658e41_924e_499c_987b_f82dc10163cc.py, line 6)
# Testing module get_activity from ./EXPORT/demo/get_activity.py...
# Error loading module get_activity.py: invalid syntax (./EXPORT/demo/get_activity.py, line 6)
# Testing module get_adapters from ./EXPORT/demo/get_adapters.py...
# Error loading module get_adapters.py: invalid syntax (./EXPORT/demo/get_adapters.py, line 6)
# Testing module get_athena_federated from ./EXPORT/demo/get_athena_federated.py...
# Error loading module get_athena_federated.py: invalid syntax (./EXPORT/demo/get_athena_federated.py, line 6)
# Testing module get_authorities from ./EXPORT/demo/get_authorities.py...
# Error loading module get_authorities.py: invalid syntax (./EXPORT/demo/get_authorities.py, line 6)
# Testing module get_azure_federated from ./EXPORT/demo/get_azure_federated.py...
# Error loading module get_azure_federated.py: invalid syntax (./EXPORT/demo/get_azure_federated.py, line 6)
# Testing module get_bigquery_federated from ./EXPORT/demo/get_bigquery_federated.py...
# Error loading module get_bigquery_federated.py: invalid syntax (./EXPORT/demo/get_bigquery_federated.py, line 6)
# Testing module get_bigquery_federated_oauth from ./EXPORT/demo/get_bigquery_federated_oauth.py...
# Error loading module get_bigquery_federated_oauth.py: invalid syntax (./EXPORT/demo/get_bigquery_federated_oauth.py, line 6)
# Testing module get_cards from ./EXPORT/demo/get_cards.py...
# Testing get_cards.get_cards...
# 🚀 Making get request to https://domo-community.domo.com/api/content/v1/cards
# Headers: {'accept': '*/*', 'x-domo-developer-token': '83ece44f1451d4b581e1191f98cd411164f0b5b6ad2755b3', 'base_url': 'https://domo-community.domo.com'}
# Params: {'urns': 'undefined', 'parts': 'certification,datasources,dateInfo,drillPathURNs,library,metadata,metadataOverrides,owners,slicers,subscriptions', 'includefiltered': 'true'}
# Data: None
# JSON: None
#   Status: 400
# Running test function get_cards.test_get_cards...
#   Error: get_cards() got an unexpected keyword argument 'includeFiltered'
# Updated get_cards.py with test results
# Testing module get_companysettings from ./EXPORT/demo/get_companysettings.py...
# Error loading module get_companysettings.py: invalid syntax (./EXPORT/demo/get_companysettings.py, line 6)
# Testing module get_config from ./EXPORT/demo/get_config.py...
# Error loading module get_config.py: invalid syntax (./EXPORT/demo/get_config.py, line 6)
# Testing module get_db2_federated from ./EXPORT/demo/get_db2_federated.py...
# Error loading module get_db2_federated.py: invalid syntax (./EXPORT/demo/get_db2_federated.py, line 6)
# Testing module get_department from ./EXPORT/demo/get_department.py...
# Error loading module get_department.py: invalid syntax (./EXPORT/demo/get_department.py, line 6)
# Testing module get_domopolicymanaged_last_export from ./EXPORT/demo/get_domopolicymanaged_last_export.py...
# Error loading module get_domopolicymanaged_last_export.py: invalid syntax (./EXPORT/demo/get_domopolicymanaged_last_export.py, line 6)
# Testing module get_domopolicymanaged_last_export_date from ./EXPORT/demo/get_domopolicymanaged_last_export_date.py...
# Error loading module get_domopolicymanaged_last_export_date.py: invalid syntax (./EXPORT/demo/get_domopolicymanaged_last_export_date.py, line 6)
# Testing module get_free_invite from ./EXPORT/demo/get_free_invite.py...
# Error loading module get_free_invite.py: invalid syntax (./EXPORT/demo/get_free_invite.py, line 6)
# Testing module get_hana_federated from ./EXPORT/demo/get_hana_federated.py...
# Error loading module get_hana_federated.py: invalid syntax (./EXPORT/demo/get_hana_federated.py, line 6)
# Testing module get_index from ./EXPORT/demo/get_index.py...
# Error loading module get_index.py: invalid syntax (./EXPORT/demo/get_index.py, line 6)
# Testing module get_indexed from ./EXPORT/demo/get_indexed.py...
# Error loading module get_indexed.py: invalid syntax (./EXPORT/demo/get_indexed.py, line 6)
# Testing module get_keys from ./EXPORT/demo/get_keys.py...
# Error loading module get_keys.py: invalid syntax (./EXPORT/demo/get_keys.py, line 6)
# Testing module get_model from ./EXPORT/demo/get_model.py...
# Error loading module get_model.py: invalid syntax (./EXPORT/demo/get_model.py, line 6)
# Testing module get_mysql_federated from ./EXPORT/demo/get_mysql_federated.py...
# Error loading module get_mysql_federated.py: invalid syntax (./EXPORT/demo/get_mysql_federated.py, line 6)
# Testing module get_nocompute from ./EXPORT/demo/get_nocompute.py...
# Error loading module get_nocompute.py: invalid syntax (./EXPORT/demo/get_nocompute.py, line 6)
# Testing module get_oracle_federated from ./EXPORT/demo/get_oracle_federated.py...
# Error loading module get_oracle_federated.py: invalid syntax (./EXPORT/demo/get_oracle_federated.py, line 6)
# Testing module get_permissions from ./EXPORT/demo/get_permissions.py...
# Error loading module get_permissions.py: invalid syntax (./EXPORT/demo/get_permissions.py, line 6)
# Testing module get_postgres_federated from ./EXPORT/demo/get_postgres_federated.py...
# Error loading module get_postgres_federated.py: invalid syntax (./EXPORT/demo/get_postgres_federated.py, line 6)
# Testing module get_presto_federated from ./EXPORT/demo/get_presto_federated.py...
# Error loading module get_presto_federated.py: invalid syntax (./EXPORT/demo/get_presto_federated.py, line 6)
# Testing module get_profiles from ./EXPORT/demo/get_profiles.py...
# Error loading module get_profiles.py: invalid syntax (./EXPORT/demo/get_profiles.py, line 6)
# Testing module get_providers from ./EXPORT/demo/get_providers.py...
# Error loading module get_providers.py: invalid syntax (./EXPORT/demo/get_providers.py, line 6)
# Testing module get_redshift_federated from ./EXPORT/demo/get_redshift_federated.py...
# Error loading module get_redshift_federated.py: invalid syntax (./EXPORT/demo/get_redshift_federated.py, line 6)
# Testing module get_roles from ./EXPORT/demo/get_roles.py...
# Error loading module get_roles.py: invalid syntax (./EXPORT/demo/get_roles.py, line 6)
# Testing module get_saved from ./EXPORT/demo/get_saved.py...
# Error loading module get_saved.py: invalid syntax (./EXPORT/demo/get_saved.py, line 6)
# Testing module get_snowflake_federated from ./EXPORT/demo/get_snowflake_federated.py...
# Error loading module get_snowflake_federated.py: invalid syntax (./EXPORT/demo/get_snowflake_federated.py, line 6)
# Testing module get_snowflake_federated_keypair from ./EXPORT/demo/get_snowflake_federated_keypair.py...
# Error loading module get_snowflake_federated_keypair.py: invalid syntax (./EXPORT/demo/get_snowflake_federated_keypair.py, line 6)
# Testing module get_snowflake_federated_oauth from ./EXPORT/demo/get_snowflake_federated_oauth.py...
# Error loading module get_snowflake_federated_oauth.py: invalid syntax (./EXPORT/demo/get_snowflake_federated_oauth.py, line 6)
# Testing module get_sqlserver_federated from ./EXPORT/demo/get_sqlserver_federated.py...
# Error loading module get_sqlserver_federated.py: invalid syntax (./EXPORT/demo/get_sqlserver_federated.py, line 6)
# Testing module get_teams from ./EXPORT/demo/get_teams.py...
# Error loading module get_teams.py: invalid syntax (./EXPORT/demo/get_teams.py, line 6)
# Testing module get_teradata_federated from ./EXPORT/demo/get_teradata_federated.py...
# Error loading module get_teradata_federated.py: invalid syntax (./EXPORT/demo/get_teradata_federated.py, line 6)
# Testing module get_title from ./EXPORT/demo/get_title.py...
# Error loading module get_title.py: invalid syntax (./EXPORT/demo/get_title.py, line 6)
# Testing module get_trino_federated from ./EXPORT/demo/get_trino_federated.py...
# Error loading module get_trino_federated.py: invalid syntax (./EXPORT/demo/get_trino_federated.py, line 6)
# Testing module get_userroleiddefault from ./EXPORT/demo/get_userroleiddefault.py...
# Error loading module get_userroleiddefault.py: invalid syntax (./EXPORT/demo/get_userroleiddefault.py, line 6)
# Testing module get_userrolesallowlist from ./EXPORT/demo/get_userrolesallowlist.py...
# Error loading module get_userrolesallowlist.py: invalid syntax (./EXPORT/demo/get_userrolesallowlist.py, line 6)
# Testing module get_users from ./EXPORT/demo/get_users.py...
# Error loading module get_users.py: invalid syntax (./EXPORT/demo/get_users.py, line 6)
# Testing module get_vertica_federated from ./EXPORT/demo/get_vertica_federated.py...
# Error loading module get_vertica_federated.py: invalid syntax (./EXPORT/demo/get_vertica_federated.py, line 6)
# Testing module get_watson_federated from ./EXPORT/demo/get_watson_federated.py...
# Error loading module get_watson_federated.py: invalid syntax (./EXPORT/demo/get_watson_federated.py, line 6)
# Testing module patch_1950208331 from ./EXPORT/demo/patch_1950208331.py...
# Error loading module patch_1950208331.py: invalid syntax (./EXPORT/demo/patch_1950208331.py, line 6)
# Testing module post_84658e41_924e_499c_987b_f82dc10163cc from ./EXPORT/demo/post_84658e41_924e_499c_987b_f82dc10163cc.py...
# Error loading module post_84658e41_924e_499c_987b_f82dc10163cc.py: invalid syntax (./EXPORT/demo/post_84658e41_924e_499c_987b_f82dc10163cc.py, line 6)
# Testing module post_access from ./EXPORT/demo/post_access.py...
# Error loading module post_access.py: invalid syntax (./EXPORT/demo/post_access.py, line 6)
# Testing module post_authenticate from ./EXPORT/demo/post_authenticate.py...
# Error loading module post_authenticate.py: invalid syntax (./EXPORT/demo/post_authenticate.py, line 6)
# Testing module post_bulk from ./EXPORT/demo/post_bulk.py...
# Error loading module post_bulk.py: invalid syntax (./EXPORT/demo/post_bulk.py, line 6)
# Testing module post_clickdata from ./EXPORT/demo/post_clickdata.py...
# Error loading module post_clickdata.py: invalid syntax (./EXPORT/demo/post_clickdata.py, line 6)
# Testing module post_clog from ./EXPORT/demo/post_clog.py...
# Error loading module post_clog.py: invalid syntax (./EXPORT/demo/post_clog.py, line 6)
# Testing module post_create from ./EXPORT/demo/post_create.py...
# Error loading module post_create.py: invalid syntax (./EXPORT/demo/post_create.py, line 6)
# Testing module post_domoweb from ./EXPORT/demo/post_domoweb.py...
# Error loading module post_domoweb.py: invalid syntax (./EXPORT/demo/post_domoweb.py, line 6)
# Testing module post_get from ./EXPORT/demo/post_get.py...
# Error loading module post_get.py: invalid syntax (./EXPORT/demo/post_get.py, line 6)
# Testing module post_list from ./EXPORT/demo/post_list.py...
# Error loading module post_list.py: invalid syntax (./EXPORT/demo/post_list.py, line 6)
# Testing module post_me from ./EXPORT/demo/post_me.py...
# Error loading module post_me.py: invalid syntax (./EXPORT/demo/post_me.py, line 6)
# Testing module post_query from ./EXPORT/demo/post_query.py...
# Error loading module post_query.py: invalid syntax (./EXPORT/demo/post_query.py, line 6)
# Testing module post_search from ./EXPORT/demo/post_search.py...
# Error loading module post_search.py: invalid syntax (./EXPORT/demo/post_search.py, line 6)
# Testing module post_suggest from ./EXPORT/demo/post_suggest.py...
# Error loading module post_suggest.py: invalid syntax (./EXPORT/demo/post_suggest.py, line 6)
# Testing module put_84658e41_924e_499c_987b_f82dc10163cc from ./EXPORT/demo/put_84658e41_924e_499c_987b_f82dc10163cc.py...
# Error loading module put_84658e41_924e_499c_987b_f82dc10163cc.py: invalid syntax (./EXPORT/demo/put_84658e41_924e_499c_987b_f82dc10163cc.py, line 6)
# Testing module put_counts from ./EXPORT/demo/put_counts.py...
# Error loading module put_counts.py: invalid syntax (./EXPORT/demo/put_counts.py, line 6)
# Testing module put_render from ./EXPORT/demo/put_render.py...
# Error loading module put_render.py: invalid syntax (./EXPORT/demo/put_render.py, line 6)
#
# Test Summary: 0/73 successful
