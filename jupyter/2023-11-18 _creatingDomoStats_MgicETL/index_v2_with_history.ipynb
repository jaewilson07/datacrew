# %% [raw]
# ---
# title: Tutorial - Generate a DomoStats dataset using DomoLibrary
# author: [Jae Wilson]
# date: 2023-11-28
# categories: ['DomoStats', 'MagicETL']
# ---

# %%
# pip install --upgrade domolibrary

# %%
import domolibrary

domolibrary.__version__
# Out:
# '4.0.1'

# %% [markdown]
# # retrieve Authentication credentials
# Don't store your password on the internet!!!

# %%
import os

domo_username = os.environ.get("DOMO_USERNAME")
domo_instance = "domo-community"
domo_password = os.environ.get("DOJO_PASSWORD")

TEST_DATAFLOW_ID = 108

# %%
import domolibrary.client.DomoAuth as dmda

auth = dmda.DomoFullAuth(
    domo_username=domo_username,
    domo_password=domo_password,
    domo_instance=domo_instance,
)

await auth.print_is_token()

assert auth.token
# Out:
# 🎉 full_auth token retrieved from domo-community ⚙️

# %% [markdown]
# # Retrieve Data
# - How do you handle looping??
# - How do you handle 'fast' code execution? (asynchronous code execution)
#
# * Will one request be enough?
#     * get all dataflow
#     * for each dataflow retrieve the correct information"

# %%
import domolibrary.classes.DomoDatacenter as dmdc
from typing import List


async def get_dataflow_ids(auth: dmda.DomoAuth) -> List[int]:
    """searches domo datacenter and returns a list of dataflow_ids"""

    domo_datacenter = dmdc.DomoDatacenter(auth=auth)

    dataflows_ls = await domo_datacenter.search_datacenter(
        auth=auth,
        entity_type="DATAFLOW",
        additional_filters_ls=[
            {
                "filterType": "term",
                "field": "data_flow_type",
                "value": "MAGIC",
                "name": "Magic ETL v2",
                "not": False,
            }
        ],
    )

    return [dataflow_obj["databaseId"] for dataflow_obj in dataflows_ls]


dataflow_ids = await get_dataflow_ids(auth)
dataflow_ids[0:5]
# Out:
# ['340', '131', '227', '37', '185']

# %%
import domolibrary.classes.DomoDataflow as dmdf
import domolibrary.utils.chunk_execution as ce
from typing import List


async def get_dataflows(dataflow_ids_ls: List[int]) -> List[dmdf.DomoDataflow]:
    """retrieves dataflow metadata from a list of dataflows"""

    return await ce.gather_with_concurrency(
        *[
            dmdf.DomoDataflow.get_from_id(dataflow_id=dataflow_id, auth=auth)
            for dataflow_id in dataflow_ids_ls
        ],
        n=20
    )


domo_dataflow_ls = await get_dataflows([TEST_DATAFLOW_ID])
domo_dataflow = domo_dataflow_ls[0]
domo_dataflow
# Out:
# DomoDataflow(id=108, name='Datasets_lineage', owner=None, description=None, tags=None, actions=[DomoDataflow_Action(id='dce3487e-6a2d-49a2-afd4-1f7867cb3b95', type='LoadFromVault', name='Governance_datasets', datasource_id='42917df1-fa58-483f-a290-5fe95ccda4ed', sql=None, depends_on=None, parent_actions=None), DomoDataflow_Action(id='df709f9b-0e6f-4f69-8b66-aa7411028db8', type='LoadFromVault', name='Governance_dataflow_details', datasource_id='260a54f7-9636-4eac-9a24-39e56d9b2f5d', sql=None, depends_on=None, parent_actions=None), DomoDataflow_Action(id='3b3396dd-a673-4211-868f-abbbcc4ce0a3', type='SelectValues', name='Datasets', datasource_id=None, sql=None, depends_on=['dce3487e-6a2d-49a2-afd4-1f7867cb3b95'], parent_actions=[DomoDataflow_Action(id='dce3487e-6a2d-49a2-afd4-1f7867cb3b95', type='LoadFromVault', name='Governance_datasets', datasource_id='42917df1-fa58-483f-a290-5fe95ccda4ed', sql=None, depends_on=None, parent_actions=None)]), DomoDataflow_Action(id='7e839c17-3e1a-4938-86d4-1b19d61c3662', type='SelectValues', name='Dataflow Details', datasource_id=None, sql=None, depends_on=['df709f9b-0e6f-4f69-8b66-aa7411028db8'], parent_actions=[DomoDataflow_Action(id='df709f9b-0e6f-4f69-8b66-aa7411028db8', type='LoadFromVault', name='Governance_dataflow_details', datasource_id='260a54f7-9636-4eac-9a24-39e56d9b2f5d', sql=None, depends_on=None, parent_actions=None)]), DomoDataflow_Action(id='b285a26d-cc81-4ac9-bfc5-68effba45241', type='Filter', name='Filter Rows', datasource_id=None, sql=None, depends_on=['df709f9b-0e6f-4f69-8b66-aa7411028db8'], parent_actions=[DomoDataflow_Action(id='df709f9b-0e6f-4f69-8b66-aa7411028db8', type='LoadFromVault', name='Governance_dataflow_details', datasource_id='260a54f7-9636-4eac-9a24-39e56d9b2f5d', sql=None, depends_on=None, parent_actions=None)]), DomoDataflow_Action(id='741d4ee4-32e9-47ca-8a2d-98f075d17518', type='SelectValues', name='Select Columns', datasource_id=None, sql=None, depends_on=['b285a26d-cc81-4ac9-bfc5-68effba45241'], parent_actions=[DomoDataflow_Action(id='b285a26d-cc81-4ac9-bfc5-68effba45241', type='Filter', name='Filter Rows', datasource_id=None, sql=None, depends_on=['df709f9b-0e6f-4f69-8b66-aa7411028db8'], parent_actions=[DomoDataflow_Action(id='df709f9b-0e6f-4f69-8b66-aa7411028db8', type='LoadFromVault', name='Governance_dataflow_details', datasource_id='260a54f7-9636-4eac-9a24-39e56d9b2f5d', sql=None, depends_on=None, parent_actions=None)])]), DomoDataflow_Action(id='b1ec014b-66d8-4518-84fc-7c6579be9749', type='ExpressionEvaluator', name='Add Formula', datasource_id=None, sql=None, depends_on=['741d4ee4-32e9-47ca-8a2d-98f075d17518'], parent_actions=[DomoDataflow_Action(id='741d4ee4-32e9-47ca-8a2d-98f075d17518', type='SelectValues', name='Select Columns', datasource_id=None, sql=None, depends_on=['b285a26d-cc81-4ac9-bfc5-68effba45241'], parent_actions=[DomoDataflow_Action(id='b285a26d-cc81-4ac9-bfc5-68effba45241', type='Filter', name='Filter Rows', datasource_id=None, sql=None, depends_on=['df709f9b-0e6f-4f69-8b66-aa7411028db8'], parent_actions=[DomoDataflow_Action(id='df709f9b-0e6f-4f69-8b66-aa7411028db8', type='LoadFromVault', name='Governance_dataflow_details', datasource_id='260a54f7-9636-4eac-9a24-39e56d9b2f5d', sql=None, depends_on=None, parent_actions=None)])])]), DomoDataflow_Action(id='0d4e85e7-b988-4492-9340-199869d5a66b', type='Unique', name='Remove Duplicates', datasource_id=None, sql=None, depends_on=['b1ec014b-66d8-4518-84fc-7c6579be9749'], parent_actions=[DomoDataflow_Action(id='b1ec014b-66d8-4518-84fc-7c6579be9749', type='ExpressionEvaluator', name='Add Formula', datasource_id=None, sql=None, depends_on=['741d4ee4-32e9-47ca-8a2d-98f075d17518'], parent_actions=[DomoDataflow_Action(id='741d4ee4-32e9-47ca-8a2d-98f075d17518', type='SelectValues', name='Select Columns', datasource_id=None, sql=None, depends_on=['b285a26d-cc81-4ac9-bfc5-68effba45241'], parent_actions=[DomoDataflow_Action(id='b285a26d-cc81-4ac9-bfc5-68effba45241', type='Filter', name='Filter Rows' ...

# %%
import pandas as pd


async def generate_version_action_pdf(domo_dataflow: dmdf.DomoDataflow) -> pd.DataFrame:
    """retrieves dataflow definition version history of a dataflow"""

    dataflow_versions = await domo_dataflow.get_versions()

    if not domo_dataflow.versions:
        return pd.DataFrame()

    df = pd.DataFrame(
        [
            {
                "dataflow_id": dataflow_version.id,
                "dataflow_version": dataflow_version.version_id,
                "dataflow_name": dataflow_version.name,
                **domo_action.__dict__,
            }
            for dataflow_version in dataflow_versions
            for domo_action in dataflow_version.actions
        ]
    )

    df.drop(columns=["parent_actions", "datasource_id", "sql"], inplace=True)
    df.rename(columns={"id": "tile_id", "type": "tile_type"}, inplace=True)

    return df


await generate_version_action_pdf(domo_dataflow)
# Out:
#     dataflow_id  dataflow_version     dataflow_name  \
# 0           108               448  Datasets_lineage
# 1           108               448  Datasets_lineage
# 2           108               448  Datasets_lineage
# 3           108               448  Datasets_lineage
# 4           108               448  Datasets_lineage
# 5           108               448  Datasets_lineage
# 6           108               448  Datasets_lineage
# 7           108               448  Datasets_lineage
# 8           108               448  Datasets_lineage
# 9           108               448  Datasets_lineage
# 10          108               448  Datasets_lineage
# 11          108               443  Datasets_lineage
# 12          108               443  Datasets_lineage
# 13          108               443  Datasets_lineage
# 14          108               443  Datasets_lineage
# 15          108               443  Datasets_lineage
# 16          108               443  Datasets_lineage
# 17          108               443  Datasets_lineage
# 18          108               443  Datasets_lineage
# 19          108               443  Datasets_lineage
# 20          108               443  Datasets_lineage
# 21          108               442  Datasets_lineage
# 22          108               442  Datasets_lineage
# 23          108               442  Datasets_lineage
# 24          108               442  Datasets_lineage
# 25          108               442  Datasets_lineage
# 26          108               442  Datasets_lineage
# 27          108               442  Datasets_lineage
# 28          108               442  Datasets_lineage
# 29          108               442  Datasets_lineage
# 30          108               442  Datasets_lineage
# 31          108               441  Datasets_lineage
# 32          108               441  Datasets_lineage
# 33          108               441  Datasets_lineage
# 34          108               441  Datasets_lineage
# 35          108               441  Datasets_lineage
# 36          108               441  Datasets_lineage
#
#                                  tile_id            tile_type  \
# 0   dce3487e-6a2d-49a2-afd4-1f7867cb3b95        LoadFromVault
# 1   df709f9b-0e6f-4f69-8b66-aa7411028db8        LoadFromVault
# 2   3b3396dd-a673-4211-868f-abbbcc4ce0a3         SelectValues
# 3   7e839c17-3e1a-4938-86d4-1b19d61c3662         SelectValues
# 4   b285a26d-cc81-4ac9-bfc5-68effba45241               Filter
# 5   741d4ee4-32e9-47ca-8a2d-98f075d17518         SelectValues
# 6   b1ec014b-66d8-4518-84fc-7c6579be9749  ExpressionEvaluator
# 7   2333341b-3a52-4b43-b72d-4ace763a9d1f             UnionAll
# 8   33a5f316-cb1e-4c2c-bf10-911396a5ae97   PythonEngineAction
# 9   dffae0ba-4e21-457f-b190-9af841e5f771       PublishToVault
# 10  0d4e85e7-b988-4492-9340-199869d5a66b               Unique
# 11  dce3487e-6a2d-49a2-afd4-1f7867cb3b95        LoadFromVault
# 12  df709f9b-0e6f-4f69-8b66-aa7411028db8        LoadFromVault
# 13  3b3396dd-a673-4211-868f-abbbcc4ce0a3         SelectValues
# 14  7e839c17-3e1a-4938-86d4-1b19d61c3662         SelectValues
# 15  b285a26d-cc81-4ac9-bfc5-68effba45241               Filter
# 16  741d4ee4-32e9-47ca-8a2d-98f075d17518         SelectValues
# 17  b1ec014b-66d8-4518-84fc-7c6579be9749  ExpressionEvaluator
# 18  2333341b-3a52-4b43-b72d-4ace763a9d1f             UnionAll
# 19  33a5f316-cb1e-4c2c-bf10-911396a5ae97   PythonEngineAction
# 20  dffae0ba-4e21-457f-b190-9af841e5f771       PublishToVault
# 21  dce3487e-6a2d-49a2-afd4-1f7867cb3b95        LoadFromVault
# 22  df709f9b-0e6f-4f69-8b66-aa7411028db8        LoadFromVault
# 23  3b3396dd-a673-4211-868f-abbbcc4ce0a3         SelectValues
# 24  7e839c17-3e1a-4938-86d4-1b19d61c3662         SelectValues
# 25  33a5f316-cb1e-4c2c-bf10-911396a5ae97   PythonEngineAction
# 26  dffae0ba-4e21-457f-b190-9af841e5f771       PublishToVault
# 27  b285a26d-cc81-4ac9-bfc5-68effba45241               Filter
# 28  741d4ee4-32e9-47ca-8a2d-98f075d17518         SelectValues
# 29  b1ec014b-66d8-4518-84fc-7c6579be9749  ExpressionEvaluator
# 30  2333341b-3a52-4b43-b72d-4ace763a9d1f             UnionAll
# 31  dce3487e-6a2d-49a2-afd4-1f7867cb3b95        LoadFromVault
# 32  df709f9b-0e6f-4f69-8b66-aa7411028db8        LoadFromVault
# 33  3b3396dd-a673-4211-868f-abbbcc4ce0a3         SelectValues
# 34  7e839c17-3e1a-4938-86d4-1b19d61c3662         SelectValues
# 35  33a5f316-cb1e-4c2c-bf10-911396a5ae97   PythonEngineAction
# 36  dffae0ba-4e21-457f-b190-9af841e5f771       PublishToVault
#
#                                 name  \
# 0                Governance_datasets
# 1        Governance_dataflow_details
# 2                           Datasets
# 3                   Dataflow Details
# 4                        Filter Rows
# 5                     Select Columns
# 6                        Add Formula
# 7   Dataflow Details With datafusion
# 8                      Python Script
# 9                   Datasets_lineage
# 10                 Remove Duplicates
# 11               Governance_datasets
# 12       Governance_dataflow_details
# 13                          Datasets
# 14                  Dataflow Details
# 15                       Filter Rows
# 16                    Select Columns
# 17                       Add Formula
# 18  Dataflow Details With datafusion
# 19                     Python Script
# 20                  Datasets_lineage
# 21               Governance_datasets
# 22       Governance_dataflow_details
# 23                          Datasets
# 24                  Dataflow Details
# 25                     Python Script
# 26                  Datasets_lineage
# 27                       Filter Rows
# 28                    Select Columns
# 29                       Add Formula
# 30  Dataflow Details With datafusion
# 31               Governance_datasets
# 32       Governance_dataflow_details
# 33                          Datasets
# 34                  Dataflow Details
# 35                     Python Script
# 36                  Datasets_lineage
#
#                                            depends_on
# 0                                                None
# 1                                                None
# 2              [dce3487e-6a2d-49a2-afd4-1f7867cb3b95]
# 3              [df709f9b-0e6f-4f69-8b66-aa7411028db8]
# 4              [df709f9b-0e6f-4f69-8b66-aa7411028db8]
# 5              [b285a26d-cc81-4ac9-bfc5-68effba45241]
# 6              [741d4ee4-32e9-47ca-8a2d-98f075d17518]
# 7   [7e839c17-3e1a-4938-86d4-1b19d61c3662, 0d4e85e...
# 8   [3b3396dd-a673-4211-868f-abbbcc4ce0a3, 2333341...
# 9              [33a5f316-cb1e-4c2c-bf10-911396a5ae97]
# 10             [b1ec014b-66d8-4518-84fc-7c6579be9749]
# 11                                               None
# 12                                               None
# 13             [dce3487e-6a2d-49a2-afd4-1f7867cb3b95]
# 14             [df709f9b-0e6f-4f69-8b66-aa7411028db8]
# 15             [df709f9b-0e6f-4f69-8b66-aa7411028db8]
# 16             [b285a26d-cc81-4ac9-bfc5-68effba45241]
# 17             [741d4ee4-32e9-47ca-8a2d-98f075d17518]
# 18  [7e839c17-3e1a-4938-86d4-1b19d61c3662, b1ec014...
# 19  [3b3396dd-a673-4211-868f-abbbcc4ce0a3, 2333341...
# 20             [33a5f316-cb1e-4c2c-bf10-911396a5ae97]
# 21                                               None
# 22                                               None
# 23             [dce3487e-6a2d-49a2-afd4-1f7867cb3b95]
# 24             [df709f9b-0e6f-4f69-8b66-aa7411028db8]
# 25  [3b3396dd-a673-4211-868f-abbbcc4ce0a3, 2333341...
# 26             [33a5f316-cb1e-4c2c-bf10-911396a5ae97]
# 27             [df709f9b-0e6f-4f69-8b66-aa7411028db8]
# 28             [b285a26d-cc81-4ac9-bfc5-68effba45241]
# 29             [741d4ee4-32e9-47ca-8a2d-98f075d17518]
# 30  [7e839c17-3e1a-4938-86d4-1b19d61c3662, b1ec014...
# 31                                               None
# 32                                               None
# 33             [dce3487e-6a2d-49a2-afd4-1f7867cb3b95]
# 34             [df709f9b-0e6f-4f69-8b66-aa7411028db8]
# 35  [3b3396dd-a673-4211-868f-abbbcc4ce0a3, 7e839c1...
# 36             [33a5f316-cb1e-4c2c-bf10-911396a5ae97]

# %%
async def generate_action_stats_df(
    domo_dataflow: dmdf.DomoDataflow,
    maximum_history: int = 10,  # number of history to look back
) -> pd.DataFrame:
    """returns execution history by tile"""

    await domo_dataflow.history.get_execution_history(maximum=maximum_history)

    if (
        not domo_dataflow.history
        or not domo_dataflow.history.execution_history
        or len(domo_dataflow.history.execution_history) == 0
    ):
        print(
            f"⚠️ dataflow {domo_dataflow.id} - {domo_dataflow.name} has never been executed"
        )
        return pd.DataFrame()

    history_ls = [
        domo_history
        for domo_history in domo_dataflow.history.execution_history
        if domo_history.action_results and len(domo_history.action_results) > 0
    ]

    df = pd.DataFrame(
        [
            {
                "dataflow_execution_id": domo_history.dataflow_execution_id,
                "dataflow_version": domo_history.dataflow_version,
                "dataflow_id": domo_history.dataflow_id,
                "dataflow_begin_time": domo_history.begin_time,
                **domo_action.__dict__,
            }
            for domo_history in history_ls
            for domo_action in domo_history.action_results
        ]
    )

    df.drop(columns=["name"], inplace=True)

    df.rename(columns={"id": "tile_id", "type": "tile_type"}, inplace=True)

    return df


stats_df = await generate_action_stats_df(domo_dataflow)
stats_df[0:5]
# Out:
#                   dataflow_execution_id  dataflow_version  dataflow_id  \
# 0  133cb2f6-caf7-4ef0-8535-4f5effdf121e               448          108
# 1  133cb2f6-caf7-4ef0-8535-4f5effdf121e               448          108
# 2  133cb2f6-caf7-4ef0-8535-4f5effdf121e               448          108
# 3  133cb2f6-caf7-4ef0-8535-4f5effdf121e               448          108
# 4  133cb2f6-caf7-4ef0-8535-4f5effdf121e               448          108
#
#   dataflow_begin_time                               tile_id  \
# 0 2022-11-04 10:06:26  dce3487e-6a2d-49a2-afd4-1f7867cb3b95
# 1 2022-11-04 10:06:26  df709f9b-0e6f-4f69-8b66-aa7411028db8
# 2 2022-11-04 10:06:26  3b3396dd-a673-4211-868f-abbbcc4ce0a3
# 3 2022-11-04 10:06:26  7e839c17-3e1a-4938-86d4-1b19d61c3662
# 4 2022-11-04 10:06:26  b285a26d-cc81-4ac9-bfc5-68effba45241
#
#                      tile_type is_success  rows_processed  \
# 0  DataHubManifestLoaderAction       True             576
# 1  DataHubManifestLoaderAction       True             367
# 2                 SelectValues       True             576
# 3                 SelectValues       True             367
# 4                       Filter       True             367
#
#                begin_time                end_time  duration_in_sec
# 0 2022-11-04 10:06:31.425 2022-11-04 10:06:32.316            0.891
# 1 2022-11-04 10:06:31.425 2022-11-04 10:06:32.314            0.889
# 2 2022-11-04 10:06:32.278 2022-11-04 10:06:32.316            0.038
# 3 2022-11-04 10:06:32.276 2022-11-04 10:06:32.277            0.001
# 4 2022-11-04 10:06:32.278 2022-11-04 10:06:32.280            0.002

# %%
async def process_instance(auth):
    dataflow_ids = await get_dataflow_ids(auth)

    domo_dataflows = await get_dataflows(dataflow_ids)

    actions_df_ls = await ce.gather_with_concurrency(
        *[
            generate_version_action_pdf(domo_dataflow)
            for domo_dataflow in domo_dataflows
        ],
        n=20
    )

    stats_df_ls = await ce.gather_with_concurrency(
        *[generate_action_stats_df(domo_dataflow) for domo_dataflow in domo_dataflows],
        n=20
    )

    actions_df = pd.concat(actions_df_ls)

    stats_df = pd.concat(stats_df_ls)

    # import domojupyter as dj
    # dj.write_dataframe(actions_df, 'MONIT_Dataflow_Tiles')
    # dj.write_dataframe(stats_df, 'MONIT_Dataflow_Stats')

    return actions_df, stats_df


base_actions_df, base_stats_df = await process_instance(auth)
# Out:
# ⚠️ dataflow 69 - Copy of gov_datasets_INT has never been executed
# ⚠️ dataflow 27 - JW_Simple Sample Set_Rolling Averages has never been executed
# ⚠️ dataflow 85 - Working Hours Test has never been executed
# ⚠️ dataflow 322 - Forecast Sales - HV has never been executed
# ⚠️ dataflow 83 - Working Hours Example has never been executed
# ⚠️ dataflow 323 - New ETL Transform has never been executed

# %%
def generate_datasets(actions_df, stats_df, dataflow_id=None, execution_id=None):

    ### filter and configure actions_df
    actions_df = actions_df.copy()
    if dataflow_id:
        actions_df = actions_df[actions_df["dataflow_id"] == dataflow_id]
    actions_df.rename(columns={"name": "tile_name"}, inplace=True)

    #### filter and configure stats_df
    stats_df = stats_df.copy()
    if execution_id:
        stats_df = stats_df[stats_df["dataflow_execution_id"] == execution_id]
    if dataflow_id:
        stats_df = stats_df[stats_df["dataflow_id"] == dataflow_id]

    stats_df = pd.merge(
        stats_df,
        actions_df[
            ["dataflow_id", "dataflow_name", "dataflow_version", "tile_id", "tile_name"]
        ],
        how="inner",
    )

    #### handle generate facts_df with one row per action and parent
    explode_df = actions_df[
        ["dataflow_id", "dataflow_version", "tile_id", "depends_on"]
    ].explode("depends_on")

    facts_df = stats_df[
        [
            "dataflow_name",
            "dataflow_execution_id",
            "dataflow_version",
            "dataflow_id",
            "tile_id",
            "tile_name",
            "tile_type",
            "rows_processed",
            "dataflow_begin_time",
            "begin_time",
            "end_time",
            "duration_in_sec",
        ]
    ]

    parent_df = facts_df[
        [
            "dataflow_execution_id",
            "dataflow_version",
            "dataflow_id",
            "tile_id",
            "tile_name",
            "tile_type",
            "rows_processed",
            "end_time",
        ]
    ].rename(
        columns={
            "tile_id": "depends_on",
            "tile_name": "parent_tile_name",
            "tile_type": "parent_tile_type",
            "rows_processed": "parent_rows_processed",
            "end_time": "parent_end_time",
        }
    )

    facts_by_parent_df = pd.merge(
        facts_df,
        explode_df,
        how="inner",
        on=["dataflow_id", "tile_id", "dataflow_version"],
    )
    facts_by_parent_df = pd.merge(
        facts_by_parent_df,
        parent_df,
        how="left",
        on=["dataflow_id", "dataflow_version", "dataflow_execution_id", "depends_on"],
    ).rename(columns={"depends_on": "parent_tile_id"})

    facts_by_parent_df["parent_end_time"] = facts_by_parent_df[
        "parent_end_time"
    ].fillna(facts_by_parent_df["begin_time"])

    facts_by_parent_df["actual_duration_in_sec"] = (
        facts_by_parent_df["end_time"] - facts_by_parent_df["parent_end_time"]
    ).dt.total_seconds()
    facts_by_parent_df["tile_delay_rank"] = facts_by_parent_df.groupby(
        ["dataflow_execution_id", "dataflow_version", "dataflow_id", "tile_id"]
    )["actual_duration_in_sec"].rank(ascending=False)

    return facts_by_parent_df.sort_values(
        by=["dataflow_id", "begin_time", "parent_tile_id"], ascending=True
    )


generate_datasets(
    base_actions_df,
    base_stats_df,
    TEST_DATAFLOW_ID,
    execution_id="1e331f2b-1db8-460d-9860-334aedc88e93",
)
# Out:
#       dataflow_name                 dataflow_execution_id  dataflow_version  \
# 0  Datasets_lineage  1e331f2b-1db8-460d-9860-334aedc88e93               441
# 1  Datasets_lineage  1e331f2b-1db8-460d-9860-334aedc88e93               441
# 2  Datasets_lineage  1e331f2b-1db8-460d-9860-334aedc88e93               441
# 4  Datasets_lineage  1e331f2b-1db8-460d-9860-334aedc88e93               441
# 5  Datasets_lineage  1e331f2b-1db8-460d-9860-334aedc88e93               441
# 3  Datasets_lineage  1e331f2b-1db8-460d-9860-334aedc88e93               441
# 6  Datasets_lineage  1e331f2b-1db8-460d-9860-334aedc88e93               441
#
#    dataflow_id                               tile_id  \
# 0          108  dce3487e-6a2d-49a2-afd4-1f7867cb3b95
# 1          108  df709f9b-0e6f-4f69-8b66-aa7411028db8
# 2          108  3b3396dd-a673-4211-868f-abbbcc4ce0a3
# 4          108  33a5f316-cb1e-4c2c-bf10-911396a5ae97
# 5          108  33a5f316-cb1e-4c2c-bf10-911396a5ae97
# 3          108  7e839c17-3e1a-4938-86d4-1b19d61c3662
# 6          108  dffae0ba-4e21-457f-b190-9af841e5f771
#
#                      tile_name                    tile_type  rows_processed  \
# 0          Governance_datasets  DataHubManifestLoaderAction           570.0
# 1  Governance_dataflow_details  DataHubManifestLoaderAction           361.0
# 2                     Datasets                 SelectValues           570.0
# 4                Python Script           PythonEngineAction           931.0
# 5                Python Script           PythonEngineAction           931.0
# 3             Dataflow Details                 SelectValues           361.0
# 6             Datasets_lineage               PublishToVault          1391.0
#
#   dataflow_begin_time              begin_time                end_time  \
# 0 2022-11-03 09:33:00 2022-11-03 09:33:05.717 2022-11-03 09:33:06.614
# 1 2022-11-03 09:33:00 2022-11-03 09:33:05.717 2022-11-03 09:33:06.656
# 2 2022-11-03 09:33:00 2022-11-03 09:33:06.609 2022-11-03 09:33:06.614
# 4 2022-11-03 09:33:00 2022-11-03 09:33:06.610 2022-11-03 09:33:15.408
# 5 2022-11-03 09:33:00 2022-11-03 09:33:06.610 2022-11-03 09:33:15.408
# 3 2022-11-03 09:33:00 2022-11-03 09:33:06.656 2022-11-03 09:33:06.656
# 6 2022-11-03 09:33:00 2022-11-03 09:33:15.348 2022-11-03 09:33:15.490
#
#    duration_in_sec                        parent_tile_id  \
# 0            0.897                                  None
# 1            0.939                                  None
# 2            0.005  dce3487e-6a2d-49a2-afd4-1f7867cb3b95
# 4            8.798  3b3396dd-a673-4211-868f-abbbcc4ce0a3
# 5            8.798  7e839c17-3e1a-4938-86d4-1b19d61c3662
# 3            0.000  df709f9b-0e6f-4f69-8b66-aa7411028db8
# 6            0.142  33a5f316-cb1e-4c2c-bf10-911396a5ae97
#
#               parent_tile_name             parent_tile_type  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2          Governance_datasets  DataHubManifestLoaderAction
# 4                     Datasets                 SelectValues
# 5             Dataflow Details                 SelectValues
# 3  Governance_dataflow_details  DataHubManifestLoaderAction
# 6                Python Script           PythonEngineAction
#
#    parent_rows_processed         parent_end_time  actual_duration_in_sec  \
# 0                    NaN 2022-11-03 09:33:05.717                   0.897
# 1                    NaN 2022-11-03 09:33:05.717                   0.939
# 2                  570.0 2022-11-03 09:33:06.614                   0.000
# 4                  570.0 2022-11-03 09:33:06.614                   8.794
# 5                  361.0 2022-11-03 09:33:06.656                   8.752
# 3                  361.0 2022-11-03 09:33:06.656                   0.000
# 6                  931.0 2022-11-03 09:33:15.408                   0.082
#
#    tile_delay_rank
# 0              1.0
# 1              1.0
# 2              1.0
# 4              1.0
# 5              2.0
# 3              1.0
# 6              1.0

# %%
generate_datasets(base_actions_df, base_stats_df, None, None)

# dj.write_dataframe(exploded_df , 'MONIT_Dataflow_Tiles_Exploded')
# Out:
#              dataflow_name                 dataflow_execution_id  \
# 11025     MetaData_Stage 1  8f77dfc7-b2fb-4f3c-9d24-1d94e0e32424
# 11026     MetaData_Stage 1  8f77dfc7-b2fb-4f3c-9d24-1d94e0e32424
# 11028     MetaData_Stage 1  8f77dfc7-b2fb-4f3c-9d24-1d94e0e32424
# 11027     MetaData_Stage 1  8f77dfc7-b2fb-4f3c-9d24-1d94e0e32424
# 11024     MetaData_Stage 1  8f77dfc7-b2fb-4f3c-9d24-1d94e0e32424
# ...                    ...                                   ...
# 11750  DEV | Swish Central  69207fcb-bc5b-4792-b82d-81a8eb05bc70
# 11747  DEV | Swish Central  69207fcb-bc5b-4792-b82d-81a8eb05bc70
# 11746  DEV | Swish Central  69207fcb-bc5b-4792-b82d-81a8eb05bc70
# 11749  DEV | Swish Central  69207fcb-bc5b-4792-b82d-81a8eb05bc70
# 11748  DEV | Swish Central  69207fcb-bc5b-4792-b82d-81a8eb05bc70
#
#        dataflow_version  dataflow_id                               tile_id  \
# 11025                19            8  d312578c-e9cb-4e3a-9dc6-662c00c93ba0
# 11026                19            8  d316ddf3-9917-4542-bf68-e1cd8397d894
# 11028                19            8  eebdf394-fc6d-40c0-895e-b325044db506
# 11027                19            8  e048f809-08ae-49c2-84be-5b7b76a99944
# 11024                19            8  8e52e4dc-fd3a-455b-9ec1-c2a404d342d0
# ...                 ...          ...                                   ...
# 11750              1062          357  f2a5bf78-3757-4be3-b555-a354df56ce53
# 11747              1062          357  d6fb5455-f89b-4c83-8714-89fd084db9bb
# 11746              1062          357  2a867c0e-8a3d-49db-81fa-d1ab6668c82c
# 11749              1062          357  1da7fa87-0d1b-434d-b018-cb80a5f3ce5a
# 11748              1062          357  24bc7117-ac36-4e5c-aee5-582d8f954cec
#
#                          tile_name                    tile_type  \
# 11025  Governance_Users and Groups  DataHubManifestLoaderAction
# 11026            Governance_Groups  DataHubManifestLoaderAction
# 11028              MetaData_Groups               PublishToVault
# 11027    MetaData_Users and Groups               PublishToVault
# 11024                       PDP? 1                     Constant
# ...                            ...                          ...
# 11750         TEST | Swish Central               PublishToVault
# 11747            Remove Duplicates                       Unique
# 11746                  Filter Rows                       Filter
# 11749          DEV | Swish Central               PublishToVault
# 11748                Add Formula 4          ExpressionEvaluator
#
#        rows_processed dataflow_begin_time              begin_time  \
# 11025            35.0 2020-07-09 16:00:07 2020-07-09 16:00:17.000
# 11026             3.0 2020-07-09 16:00:07 2020-07-09 16:00:17.000
# 11028             3.0 2020-07-09 16:00:07 2020-07-09 16:00:21.000
# 11027            35.0 2020-07-09 16:00:07 2020-07-09 16:00:21.000
# 11024            35.0 2020-07-09 16:00:07 2020-07-09 16:00:21.000
# ...               ...                 ...                     ...
# 11750         40756.0 2024-02-06 16:35:04 2024-02-06 16:35:20.967
# 11747         38111.0 2024-02-06 16:35:04 2024-02-06 16:35:21.167
# 11746         40756.0 2024-02-06 16:35:04 2024-02-06 16:35:21.167
# 11749         37924.0 2024-02-06 16:35:04 2024-02-06 16:35:21.168
# 11748         37924.0 2024-02-06 16:35:04 2024-02-06 16:35:21.168
#
#                      end_time  duration_in_sec  \
# 11025 2020-07-09 16:00:21.000            4.000
# 11026 2020-07-09 16:00:21.000            4.000
# 11028 2020-07-09 16:00:22.000            1.000
# 11027 2020-07-09 16:00:22.000            1.000
# 11024 2020-07-09 16:00:21.000            0.000
# ...                       ...              ...
# 11750 2024-02-06 16:35:24.767            3.800
# 11747 2024-02-06 16:35:24.065            2.898
# 11746 2024-02-06 16:35:24.065            2.898
# 11749 2024-02-06 16:35:24.734            3.566
# 11748 2024-02-06 16:35:24.066            2.898
#
#                              parent_tile_id             parent_tile_name  \
# 11025                                  None                          NaN
# 11026                                  None                          NaN
# 11028  0fe45cc8-7c88-48cb-a437-4656954767a6                         PDP?
# 11027  8e52e4dc-fd3a-455b-9ec1-c2a404d342d0                       PDP? 1
# 11024  d312578c-e9cb-4e3a-9dc6-662c00c93ba0  Governance_Users and Groups
# ...                                     ...                          ...
# 11750  47257e8e-8a34-41cf-a438-3c034eeb4f87             Select Columns 1
# 11747  2a867c0e-8a3d-49db-81fa-d1ab6668c82c                  Filter Rows
# 11746  47257e8e-8a34-41cf-a438-3c034eeb4f87             Select Columns 1
# 11749  24bc7117-ac36-4e5c-aee5-582d8f954cec                Add Formula 4
# 11748  d6fb5455-f89b-4c83-8714-89fd084db9bb            Remove Duplicates
#
#                   parent_tile_type  parent_rows_processed  \
# 11025                          NaN                    NaN
# 11026                          NaN                    NaN
# 11028                     Constant                    3.0
# 11027                     Constant                   35.0
# 11024  DataHubManifestLoaderAction                   35.0
# ...                            ...                    ...
# 11750                 SelectValues                40756.0
# 11747                       Filter                40756.0
# 11746                 SelectValues                40756.0
# 11749          ExpressionEvaluator                37924.0
# 11748                       Unique                38111.0
#
#               parent_end_time  actual_duration_in_sec  tile_delay_rank
# 11025 2020-07-09 16:00:17.000                   4.000              1.0
# 11026 2020-07-09 16:00:17.000                   4.000              1.0
# 11028 2020-07-09 16:00:21.000                   1.000              1.0
# 11027 2020-07-09 16:00:21.000                   1.000              1.0
# 11024 2020-07-09 16:00:21.000                   0.000              1.0
# ...                       ...                     ...              ...
# 11750 2024-02-06 16:35:24.066                   0.701              1.0
# 11747 2024-02-06 16:35:24.065                   0.000              1.0
# 11746 2024-02-06 16:35:24.066                  -0.001              1.0
# 11749 2024-02-06 16:35:24.066                   0.668              1.0
# 11748 2024-02-06 16:35:24.065                   0.001              1.0
#
# [15633 rows x 19 columns]
